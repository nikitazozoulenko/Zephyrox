# %%
from typing import Tuple, List, Union, Any, Optional, Dict, Literal, Callable
import time
import collections
import os
import sys
sys.path.append(os.path.dirname(os.getcwd()))
sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))

from tqdm import tqdm
import numpy as np
import jax
import jax.numpy as jnp
import jax.lax as lax
from jaxtyping import Array, Float, Int, PRNGKeyArray
import aeon
import pandas as pd
from preprocessing.timeseries_augmentation import normalize_mean_std_traindata, normalize_streams, augment_time, add_basepoint_zero
from aeon.regression.sklearn import RotationForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from aeon.datasets.tser_datasets import tser_soton
from aeon.datasets import load_regression, load_classification
from sklearn.linear_model import RidgeCV

from features.sig import SigTransform, LogSigTransform
from features.base import TimeseriesFeatureTransformer, TabularTimeseriesFeatures, RandomGuesser, RandomProjectionFeatures
from features.sig_neural import RandomizedSignature, TimeInhomogenousRandomizedSignature
from features.SWIM_controlled_resnet import SampledControlledResNet
from features.rocket_wrappers import RocketWrapper
from utils.utils import print_name, print_shape

jax.config.update('jax_platform_name', 'gpu') # Used to set the platform (cpu, gpu, etc.)
np.set_printoptions(precision=3, threshold=5) # Print options
# Out:
# /home/nikita/Code/zephyrox/.conda/lib/python3.10/site-packages/aeon/base/__init__.py:24: FutureWarning: The aeon package will soon be releasing v1.0.0 with the removal of legacy modules and interfaces such as BaseTransformer and BaseForecaster. This will contain breaking changes. See aeon-toolkit.org for more information. Set aeon.AEON_DEPRECATION_WARNING or the AEON_DEPRECATION_WARNING environmental variable to 'False' to disable this warning.
#   warnings.warn(
# 2024-09-24 09:25:17.727609: W external/xla/xla/service/gpu/nvptx_compiler.cc:718] The NVIDIA driver's CUDA version is 12.4 which is older than the ptxas CUDA version (12.5.82). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.

# %% [markdown]
# # Download dataset code

# %%
def get_aeon_dataset(
        dataset_name:str,
        normalize:bool = True,
        TSER_or_TSC:str = "TSER",
        extract_path = "/home/nikita/hdd/Data/",
        max_T:int = 1000,
        ):
    """Loads a dataset from the UCR/UEA archive using
    the aeon library.

    Args:
        dataset_name (str): Name of the dataset
        normalize (bool): Whether to apply z-score normalization based on
            the train set data.
        TSER_or_TSC (str): Whether to load a TSER or TSC dataset.
        extract_path (str): Path to the directory where the datasets are stored.
            Note that the datasets are stored in a subdirectory called "TSER" or "TSC".
        max_T (int): Maximum length of the time series. If the time series is longer
            than this value, it will be average pooled down.

    Returns:
        Tuple: 4-tuple of the form (X_train, y_train, X_test, y_test)
    """
    if TSER_or_TSC == "TSER":
        load_fun = load_regression 
    elif TSER_or_TSC == "TSC":
        load_fun = load_classification
    else:
        raise ValueError("TSER_or_TSC must be either 'TSER' or 'TSC'")
    
    #download
    X_train, y_train = load_fun(dataset_name, split="train", extract_path=extract_path+TSER_or_TSC+"/")
    X_test, y_test = load_fun(dataset_name, split="test", extract_path=extract_path+TSER_or_TSC+"/")

    #to jax array NOTE hardcoded no gradients
    X_train = lax.stop_gradient(jnp.array(X_train).transpose(0,2,1))
    X_test = lax.stop_gradient(jnp.array(X_test).transpose(0,2,1))
    y_train = lax.stop_gradient(jnp.array(y_train))[:, None]
    y_test = lax.stop_gradient(jnp.array(y_test))[:, None]

    #normalize
    if normalize:
        X_train, X_test = normalize_streams(X_train, X_test, max_T)
        y_train, y_test = normalize_mean_std_traindata(y_train, y_test)
        c = 5.0
        X_train = X_train.clip(-c, c)
        X_test = X_test.clip(-c, c)

    return X_train, y_train, X_test, y_test


# df = []
# for dataset_name in list(tser_soton):
#     print(dataset_name)
#     X_train, y_train, X_test, y_test = get_aeon_dataset(dataset_name)

#     N1, T, D = X_train.shape
#     N2, T, D = X_test.shape
#     metadata_row = {
#                     "Dataset": dataset_name,
#                     "N_train": N1,
#                     "N_test": N2,
#                     "T": T,
#                     "D": D,
#                     "y_train_shape": y_train.shape,
#                     "n_labels": len(np.unique(y_train)),}
#     df.append(metadata_row)
# df = pd.DataFrame(df).set_index("Dataset")
# df.to_pickle("TSER_dataset_metadata.pkl")

# %%
df_meta = pd.read_pickle("TSER_dataset_metadata.pkl")
df_meta.head()
# Out:
#                          N_train  N_test    T  D y_train_shape  n_labels
# Dataset
# FloodModeling1               471     202  266  1      (471, 1)        85
# BarCrawl6min                 140      61  360  3      (140, 1)       137
# TetuanEnergyConsumption      254     110  144  5      (254, 1)       254
# GasSensorArrayEthanol        324     140  938  1      (324, 1)         4
# FloodModeling3               429     184  266  1      (429, 1)        76

# %%
large_datasets = df_meta.query("N_train >= 2000").sort_values("N_train")
print(large_datasets)
large_datasets = list(large_datasets.index)
# Out:
#                                N_train  N_test     T  D y_train_shape  \
# Dataset
# LPGasMonitoringHomeActivity       2017     865   100  1     (2017, 1)
# MethaneMonitoringHomeActivity     2017     865   100  1     (2017, 1)
# BenzeneConcentration              3349    5163   240  8     (3349, 1)
# LiveFuelMoistureContent           3493    1510   365  7     (3493, 1)
# MadridPM10Quality                 4845    2077   168  3     (4845, 1)
# BIDMC32RR                         5471    2399  1000  2     (5471, 1)
# BIDMC32HR                         5550    2399  1000  2     (5550, 1)
# BIDMC32SpO2                       5550    2399  1000  2     (5550, 1)
# BeijingPM10Quality               11918    5048    24  9    (11918, 1)
# BeijingPM25Quality               11918    5048    24  9    (11918, 1)
# ElectricMotorTemperature         15503    6645    60  6    (15503, 1)
# DailyTemperatureLatitude         27440   11760   365  1    (27440, 1)
# PPGDalia                         43215   21482   256  4    (43215, 1)
# VentilatorPressure               52815   22635    80  2    (52815, 1)
# NewsHeadlineSentiment            58213   24951   144  3    (58213, 1)
# NewsTitleSentiment               58213   24951   144  3    (58213, 1)
# AustraliaRainfall               112186   48081    24  3   (112186, 1)
#
#                                n_labels
# Dataset
# LPGasMonitoringHomeActivity        2017
# MethaneMonitoringHomeActivity      2017
# BenzeneConcentration               2194
# LiveFuelMoistureContent             796
# MadridPM10Quality                  4825
# BIDMC32RR                           502
# BIDMC32HR                          1373
# BIDMC32SpO2                         281
# BeijingPM10Quality                  710
# BeijingPM25Quality                  575
# ElectricMotorTemperature          15502
# DailyTemperatureLatitude            954
# PPGDalia                          43211
# VentilatorPressure                38384
# NewsHeadlineSentiment             28562
# NewsTitleSentiment                10552
# AustraliaRainfall                   782

# %%
medium_datasets = df_meta.query("1000 < N_train < 2000").sort_values("N_train")
print(medium_datasets)
medium_datasets = list(medium_datasets.index)
# Out:
#                               N_train  N_test     T  D y_train_shape  n_labels
# Dataset
# BeijingIntAirportPM25Quality     1099     472    24  6     (1099, 1)       970
# WaveDataTension                  1325     568    57  1     (1325, 1)      1325
# ParkingBirmingham                1391     597    14  1     (1391, 1)      1385
# DhakaHourlyAirQuality            1447     621    24  1     (1447, 1)      1255
# MagnesiumConcentration           1560     669   895  1     (1560, 1)       904
# PotassiumConcentration           1561     669   895  1     (1561, 1)       853
# PhosphorusConcentration          1573     675   895  1     (1573, 1)       877
# IEEEPPG                          1768    1328  1000  5     (1768, 1)      1035

# %%
small_datasets = df_meta.query("N_train <= 1000").sort_values("N_train")
print(small_datasets)
small_datasets = list(small_datasets.index)
# Out:
#                               N_train  N_test    T   D y_train_shape  n_labels
# Dataset
# NaturalGasPricesSentiment          65      28   20   1       (65, 1)        65
# CardanoSentiment                   74      33   24   2       (74, 1)        66
# AppliancesEnergy                   95      42  144  24       (95, 1)        93
# DailyOilGasPrices                 133      58   30   2      (133, 1)       133
# Covid3Month                       140      61   84   1      (140, 1)       110
# BarCrawl6min                      140      61  360   3      (140, 1)       137
# Covid19Andalusia                  142      62   91   1      (142, 1)       142
# AcousticContaminationMadrid       166      72  365   1      (166, 1)       114
# BinanceCoinSentiment              184      79   24   2      (184, 1)       173
# SteamPredictor                    210      90  168   4      (210, 1)       210
# BitcoinSentiment                  232     100   24   2      (232, 1)       228
# OccupancyDetectionLight           237     103   60   3      (237, 1)       100
# HotwaterPredictor                 245     106  168   4      (245, 1)       245
# EthereumSentiment                 249     107   24   2      (249, 1)       241
# TetuanEnergyConsumption           254     110  144   5      (254, 1)       254
# ChilledWaterPredictor             321     138  168   4      (321, 1)       303
# GasSensorArrayEthanol             324     140  938   1      (324, 1)         4
# GasSensorArrayAcetone             324     140  938   1      (324, 1)         4
# SierraNevadaMountainsSnow         350     150   30   3      (350, 1)       195
# SodiumConcentration               424     183  858   1      (424, 1)       373
# ManganeseConcentration            427     184  858   1      (427, 1)       396
# IronConcentration                 427     184  858   1      (427, 1)       361
# FloodModeling3                    429     184  266   1      (429, 1)        76
# BoronConcentration                438     188  848   1      (438, 1)       235
# AluminiumConcentration            440     189  848   1      (440, 1)       381
# CopperConcentration               440     189  848   1      (440, 1)       310
# SulphurConcentration              444     191  769   1      (444, 1)       377
# CalciumConcentration              444     191  769   1      (444, 1)       405
# ZincConcentration                 445     191  769   1      (445, 1)       314
# FloodModeling2                    466     201  266   1      (466, 1)        27
# PrecipitationAndalusia            470     202  365   4      (470, 1)       467
# SolarRadiationAndalusia           470     202  365   2      (470, 1)       470
# FloodModeling1                    471     202  266   1      (471, 1)        85
# ElectricityPredictor              567     243  168   4      (567, 1)       567
# WindTurbinePower                  596     256  144   1      (596, 1)       596
# HouseholdPowerConsumption1        745     686  720   5      (745, 1)       745
# HouseholdPowerConsumption2        745     686  720   5      (745, 1)       740
# MetroInterstateTrafficVolume      849     365   24   4      (849, 1)       838

# %% [markdown]
# # Experiment code

# %%
def run_1model_1dataset(
        model: TimeseriesFeatureTransformer,
        X_train: Float[Array, "N1  T  D"],
        y_train: Float[Array, "N1  1"],
        X_test: Float[Array, "N2  T  D"],
        y_test: Float[Array, "N2  1"],
        normalize_features: bool = False,
        normalize_y: bool = True,
        apply_augment_time: bool = False,
        apply_basepoint: bool = True,
        ):

    if apply_basepoint:
        X_train = add_basepoint_zero(X_train)
        X_test = add_basepoint_zero(X_test)
    if apply_augment_time:
        X_train = augment_time(X_train)
        X_test  = augment_time(X_test)
    if normalize_y:
        y_train, y_test = normalize_mean_std_traindata(y_train, y_test)

    #fit feature model
    t0 = time.time()
    model.fit(X_train, y_train)

    #obtain features
    t1 = time.time()
    feat_train = model.transform(X_train)
    feat_test = model.transform(X_test)
    if normalize_features:
        feat_train, feat_test = normalize_mean_std_traindata(feat_train, feat_test)

    #fit ridge regression
    t2 = time.time()
    y_train = np.array(y_train)
    y_test = np.array(y_test)
    feat_train = np.array(feat_train)
    feat_test = np.array(feat_test)
    ridge = RidgeCV(alphas=np.logspace(-3, 3, 30))
    ridge.fit(feat_train, y_train)

    # predict
    pred_test = ridge.predict(feat_test)
    pred_train = ridge.predict(feat_train)
    test_rmse = np.sqrt(mean_squared_error(y_test, pred_test))
    train_rmse = np.sqrt(mean_squared_error(y_train, pred_train))
    alpha = ridge.alpha_
    t3 = time.time()
    # print("Model:", model)
    # print("train_RMSE:", train_rmse)
    # print("test_RMSE:", test_rmse)
    # print("alpha (regularization):", alpha, "\n")
    t_fit_feat = t1 - t0
    t_trans_feat = t2 - t1
    t_ridge = t3 - t2
    return train_rmse, test_rmse, alpha, t_fit_feat, t_trans_feat, t_ridge



def run_allmodels_1dataset(
        X_train: Float[Array, "N1  T  D"],
        y_train: Float[Array, "N1  1"],
        X_test: Float[Array, "N2  T  D"],
        y_test: Float[Array, "N2  1"],
        normalize_features: bool = False,
        normalize_y: bool = True,
        apply_augment_time: bool = False,
        apply_basepoint: bool = True,
        ):
    
    prng_key = jax.random.PRNGKey(999)
    max_batch = 1000
    n_features = 100
    models = [
        ["Random Guesser", RandomGuesser(prng_key, 10, max_batch)],
        ["Tabular", TabularTimeseriesFeatures(max_batch)],
        ["Sig", SigTransform(4, max_batch)],
        #["Log Sig", LogSigTransform(4, max_batch)],
        ["Randomized Signature", RandomizedSignature(
            prng_key,
            n_features,
            max_batch,
            )],
        ["Time Inhomogenous Randomized Signature", TimeInhomogenousRandomizedSignature(
            prng_key,
            n_features,
            max_batch,
            )],
        ["Sampled Controlled ResNet", SampledControlledResNet(
            prng_key,
            n_features,
            jnp.tanh,
            max_batch,
            )],
        ["Rocket", RocketWrapper(
            20000,
            10000000,
            )],
        ["Random Projection", RandomProjectionFeatures(prng_key, 5000)],
        ]
    
    results = []
    model_names = [name for name, _ in models]
    for name, model in models:
        res = run_1model_1dataset(
            model, X_train, y_train, X_test, y_test, 
            normalize_features, normalize_y, apply_augment_time, apply_basepoint
            )
        results.append(res)
    return model_names, results



def run_all_experiments(
        datasets: List[str],
        name_save: str,
        normalize_X: bool = True,
        normalize_features: bool = False,
        normalize_y: bool = True,
        apply_augment_time: bool = False,
        apply_basepoint: bool = True,
        max_T = 100,
        ):
    # Run experiments
    experiments = {}
    failed = {}
    for dataset_name in tqdm(datasets):
        t0 = time.time()
        # try:
        print(dataset_name)
        X_train, y_train, X_test, y_test = get_aeon_dataset(dataset_name, normalize_X, max_T=max_T)
        X_train, X_test = normalize_streams(X_train, X_test, max_T=max_T)
        y_train, y_test = normalize_mean_std_traindata(y_train, y_test)
        results = run_allmodels_1dataset(
            X_train, y_train, X_test, y_test, 
            normalize_features, normalize_y, apply_augment_time, apply_basepoint,
            )
        experiments[dataset_name] = results
        # except Exception as e:
        #     print(f"Error: {e}")
        #     failed[dataset_name] = e
        print(dataset_name, "Elapsed time", time.time()-t0)
    
    # Save results
    # Assuming experiments is a dict where keys are dataset names and values are tuples (model_names, results)
    attributes = ["RMSE_train", "RMSE_test", "alpha", "t_fit_feat", "t_trans_feat", "t_ridge"]
    data_list = []
    # Process the data
    for dataset_name, (model_names, results) in experiments.items():
        dataset_data = {}
        for attr_idx, attribute in enumerate(attributes):
            for model_idx, model_name in enumerate(model_names):
                dataset_data[(attribute, model_name)] = results[model_idx][attr_idx]
        data_list.append(pd.DataFrame(dataset_data, index=[dataset_name]))

    # Combine all datasets into a single DataFrame
    df = pd.concat(data_list)
    df = df.sort_index(axis=1)
    print(df)
    df.to_pickle(f"TSER_results_{name_save}.pkl")
    return df

# %%
df = run_all_experiments(medium_datasets, "medium3", max_T=100)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# BeijingIntAirportPM25Quality
#  12%|█▎        | 1/8 [00:26<03:05, 26.52s/it]
# BeijingIntAirportPM25Quality Elapsed time 26.523066997528076
# WaveDataTension
#  25%|██▌       | 2/8 [00:47<02:20, 23.37s/it]
# WaveDataTension Elapsed time 21.164180755615234
# ParkingBirmingham
#  38%|███▊      | 3/8 [01:00<01:32, 18.51s/it]
# ParkingBirmingham Elapsed time 12.719717025756836
# DhakaHourlyAirQuality
#  50%|█████     | 4/8 [01:15<01:08, 17.18s/it]
# DhakaHourlyAirQuality Elapsed time 15.148935079574585
# MagnesiumConcentration
#  62%|██████▎   | 5/8 [01:53<01:13, 24.51s/it]
# MagnesiumConcentration Elapsed time 37.491743087768555
# PotassiumConcentration
#  75%|███████▌  | 6/8 [02:27<00:56, 28.02s/it]
# PotassiumConcentration Elapsed time 34.833595514297485
# PhosphorusConcentration
#  88%|████████▊ | 7/8 [03:03<00:30, 30.52s/it]
# PhosphorusConcentration Elapsed time 35.67899775505066
# IEEEPPG
# 100%|██████████| 8/8 [05:32<00:00, 41.54s/it]
# IEEEPPG Elapsed time 148.7748191356659
#                                   RMSE_test                    \
#                              Random Guesser Random Projection
# BeijingIntAirportPM25Quality       0.970697          0.741420
# WaveDataTension                    1.071930          0.811683
# ParkingBirmingham                  1.066348          1.000519
# DhakaHourlyAirQuality              1.022880          0.198276
# MagnesiumConcentration             0.972257          0.349751
# PotassiumConcentration             0.726010          0.643590
# PhosphorusConcentration            0.925012          0.820221
# IEEEPPG                            1.533562          1.473041
#
#                                                              \
#                              Randomized Signature    Rocket
# BeijingIntAirportPM25Quality             0.868496  0.734197
# WaveDataTension                          0.985453  0.904860
# ParkingBirmingham                        1.040897  0.689770
# DhakaHourlyAirQuality                    0.415107  0.367435
# MagnesiumConcentration                   0.877982  0.332184
# PotassiumConcentration                   0.703472  0.468443
# PhosphorusConcentration                  0.909306  0.548968
# IEEEPPG                                  1.483619  1.093875
#
#                                                                              \
#                              Sampled Controlled ResNet        Sig   Tabular
# BeijingIntAirportPM25Quality                  0.696935   0.893760  0.748680
# WaveDataTension                               0.886434   0.989143  0.821681
# ParkingBirmingham                             0.773245   0.919772  1.000532
# DhakaHourlyAirQuality                         0.124193   0.435960  0.198016
# MagnesiumConcentration                        0.529521   0.849769  0.356027
# PotassiumConcentration                        0.635628   0.698375  0.647635
# PhosphorusConcentration                       0.850401   0.910623  0.820897
# IEEEPPG                                       1.270224  29.344443  1.314504
#
#                                                                      \
#                              Time Inhomogenous Randomized Signature
# BeijingIntAirportPM25Quality                               0.845856
# WaveDataTension                                            0.839360
# ParkingBirmingham                                          0.980735
# DhakaHourlyAirQuality                                      0.195287
# MagnesiumConcentration                                     0.494900
# PotassiumConcentration                                     0.649952
# PhosphorusConcentration                                    0.841762
# IEEEPPG                                                    1.518755
#
#                                  RMSE_train                    ...   t_ridge  \
#                              Random Guesser Random Projection  ...   Tabular
# BeijingIntAirportPM25Quality       0.997462          0.743531  ...  0.082337
# WaveDataTension                    0.993299          0.787235  ...  0.045864
# ParkingBirmingham                  0.997263          0.936158  ...  0.014432
# DhakaHourlyAirQuality              0.997432          0.193273  ...  0.025726
# MagnesiumConcentration             0.997119          0.343169  ...  0.052733
# PotassiumConcentration             0.997603          0.661705  ...  0.068611
# PhosphorusConcentration            0.996873          0.826201  ...  0.056033
# IEEEPPG                            0.998997          0.750781  ...  0.370454
#
#                                                                      \
#                              Time Inhomogenous Randomized Signature
# BeijingIntAirportPM25Quality                               0.041255
# WaveDataTension                                            0.032148
# ParkingBirmingham                                          0.062585
# DhakaHourlyAirQuality                                      0.057532
# MagnesiumConcentration                                     0.056003
# PotassiumConcentration                                     0.033696
# PhosphorusConcentration                                    0.055825
# IEEEPPG                                                    0.127386
#
#                                t_trans_feat                    \
#                              Random Guesser Random Projection
# BeijingIntAirportPM25Quality       0.205328          0.221961
# WaveDataTension                    0.156564          0.153406
# ParkingBirmingham                  0.155094          0.098070
# DhakaHourlyAirQuality              0.151366          0.115292
# MagnesiumConcentration             0.157568          0.233296
# PotassiumConcentration             0.106551          0.157529
# PhosphorusConcentration            0.115077          0.235343
# IEEEPPG                            0.279342          0.978058
#
#                                                                \
#                              Randomized Signature      Rocket
# BeijingIntAirportPM25Quality             0.678498   15.472171
# WaveDataTension                          0.688041   11.141991
# ParkingBirmingham                        0.510758    3.383490
# DhakaHourlyAirQuality                    0.515391    5.601440
# MagnesiumConcentration                   0.524146   22.667932
# PotassiumConcentration                   0.331817   22.870022
# PhosphorusConcentration                  0.444735   22.867164
# IEEEPPG                                  0.921633  125.037869
#
#                                                                             \
#                              Sampled Controlled ResNet       Sig   Tabular
# BeijingIntAirportPM25Quality                  0.682048  0.634689  0.288945
# WaveDataTension                               0.508482  0.510971  0.291263
# ParkingBirmingham                             0.512743  0.424652  0.279267
# DhakaHourlyAirQuality                         0.522077  0.464927  0.277628
# MagnesiumConcentration                        0.581486  0.455045  0.291596
# PotassiumConcentration                        0.381516  0.204640  0.100252
# PhosphorusConcentration                       0.505220  0.335282  0.162650
# IEEEPPG                                       0.843427  0.684899  0.334387
#
#
#                              Time Inhomogenous Randomized Signature
# BeijingIntAirportPM25Quality                               0.377372
# WaveDataTension                                            0.336241
# ParkingBirmingham                                          0.313995
# DhakaHourlyAirQuality                                      0.328590
# MagnesiumConcentration                                     0.379675
# PotassiumConcentration                                     0.201653
# PhosphorusConcentration                                    0.312422
# IEEEPPG                                                    0.428688
#
# [8 rows x 48 columns]

# %%
df["RMSE_test"].mean()
# Out:
# Random Guesser                            1.036087
# Random Projection                         0.754813
# Randomized Signature                      0.910541
# Rocket                                    0.642466
# Sampled Controlled ResNet                 0.720823
# Sig                                       4.380231
# Tabular                                   0.738496
# Time Inhomogenous Randomized Signature    0.795826
# dtype: float64

# %%
df["RMSE_test"].rank(axis=1).mean()
# Out:
# Random Guesser                            7.875
# Random Projection                         3.000
# Randomized Signature                      6.250
# Rocket                                    2.125
# Sampled Controlled ResNet                 2.750
# Sig                                       6.375
# Tabular                                   3.500
# Time Inhomogenous Randomized Signature    4.125
# dtype: float64

# %%
df["RMSE_test"].rank(axis=1)
# Out:
#                               Random Guesser  Random Projection  \
# BeijingIntAirportPM25Quality             8.0                3.0
# WaveDataTension                          8.0                1.0
# ParkingBirmingham                        8.0                5.0
# DhakaHourlyAirQuality                    8.0                4.0
# MagnesiumConcentration                   8.0                2.0
# PotassiumConcentration                   8.0                3.0
# PhosphorusConcentration                  8.0                2.0
# IEEEPPG                                  7.0                4.0
#
#                               Randomized Signature  Rocket  \
# BeijingIntAirportPM25Quality                   6.0     2.0
# WaveDataTension                                6.0     5.0
# ParkingBirmingham                              7.0     1.0
# DhakaHourlyAirQuality                          6.0     5.0
# MagnesiumConcentration                         7.0     1.0
# PotassiumConcentration                         7.0     1.0
# PhosphorusConcentration                        6.0     1.0
# IEEEPPG                                        5.0     1.0
#
#                               Sampled Controlled ResNet  Sig  Tabular  \
# BeijingIntAirportPM25Quality                        1.0  7.0      4.0
# WaveDataTension                                     4.0  7.0      2.0
# ParkingBirmingham                                   2.0  3.0      6.0
# DhakaHourlyAirQuality                               1.0  7.0      3.0
# MagnesiumConcentration                              5.0  6.0      3.0
# PotassiumConcentration                              2.0  6.0      4.0
# PhosphorusConcentration                             5.0  7.0      3.0
# IEEEPPG                                             2.0  8.0      3.0
#
#                               Time Inhomogenous Randomized Signature
# BeijingIntAirportPM25Quality                                     5.0
# WaveDataTension                                                  3.0
# ParkingBirmingham                                                4.0
# DhakaHourlyAirQuality                                            2.0
# MagnesiumConcentration                                           4.0
# PotassiumConcentration                                           5.0
# PhosphorusConcentration                                          4.0
# IEEEPPG                                                          6.0

# %%
df["RMSE_test"]
# Out:
#                               Random Guesser  Random Projection  \
# BeijingIntAirportPM25Quality        0.970697           0.741420
# WaveDataTension                     1.071930           0.811683
# ParkingBirmingham                   1.066348           1.000519
# DhakaHourlyAirQuality               1.022880           0.198276
# MagnesiumConcentration              0.972257           0.349751
# PotassiumConcentration              0.726010           0.643590
# PhosphorusConcentration             0.925012           0.820221
# IEEEPPG                             1.533562           1.473041
#
#                               Randomized Signature    Rocket  \
# BeijingIntAirportPM25Quality              0.868496  0.734197
# WaveDataTension                           0.985453  0.904860
# ParkingBirmingham                         1.040897  0.689770
# DhakaHourlyAirQuality                     0.415107  0.367435
# MagnesiumConcentration                    0.877982  0.332184
# PotassiumConcentration                    0.703472  0.468443
# PhosphorusConcentration                   0.909306  0.548968
# IEEEPPG                                   1.483619  1.093875
#
#                               Sampled Controlled ResNet        Sig   Tabular  \
# BeijingIntAirportPM25Quality                   0.696935   0.893760  0.748680
# WaveDataTension                                0.886434   0.989143  0.821681
# ParkingBirmingham                              0.773245   0.919772  1.000532
# DhakaHourlyAirQuality                          0.124193   0.435960  0.198016
# MagnesiumConcentration                         0.529521   0.849769  0.356027
# PotassiumConcentration                         0.635628   0.698375  0.647635
# PhosphorusConcentration                        0.850401   0.910623  0.820897
# IEEEPPG                                        1.270224  29.344443  1.314504
#
#                               Time Inhomogenous Randomized Signature
# BeijingIntAirportPM25Quality                                0.845856
# WaveDataTension                                             0.839360
# ParkingBirmingham                                           0.980735
# DhakaHourlyAirQuality                                       0.195287
# MagnesiumConcentration                                      0.494900
# PotassiumConcentration                                      0.649952
# PhosphorusConcentration                                     0.841762
# IEEEPPG                                                     1.518755

# %%
df_med = pd.read_pickle("TSER_results_medium.pkl")
df_med["RMSE_test"].mean()
# Out:
# MultiRocket                               0.665585
# Random Guesser                            1.049658
# Randomized Signature                      0.828023
# Sampled Controlled ResNet                 0.782996
# Sig                                       4.380231
# Tabular                                   0.738496
# Time Inhomogenous Randomized Signature    0.806068
# dtype: float64

# %%
df_med["RMSE_test"].rank(axis=1).mean()
# Out:
# MultiRocket                               1.875
# Random Guesser                            6.875
# Randomized Signature                      4.250
# Sampled Controlled ResNet                 3.125
# Sig                                       5.750
# Tabular                                   2.250
# Time Inhomogenous Randomized Signature    3.875
# dtype: float64

# %%
df_med["RMSE_test"].rank(axis=1)
# Out:
#                               MultiRocket  Random Guesser  \
# BeijingIntAirportPM25Quality          2.0             7.0
# WaveDataTension                       6.0             7.0
# ParkingBirmingham                     1.0             7.0
# DhakaHourlyAirQuality                 1.0             7.0
# MagnesiumConcentration                2.0             7.0
# PotassiumConcentration                1.0             7.0
# PhosphorusConcentration               1.0             7.0
# IEEEPPG                               1.0             6.0
#
#                               Randomized Signature  Sampled Controlled ResNet  \
# BeijingIntAirportPM25Quality                   3.0                        4.0
# WaveDataTension                                4.0                        3.0
# ParkingBirmingham                              6.0                        2.0
# DhakaHourlyAirQuality                          5.0                        3.0
# MagnesiumConcentration                         5.0                        3.0
# PotassiumConcentration                         4.0                        2.0
# PhosphorusConcentration                        5.0                        3.0
# IEEEPPG                                        2.0                        5.0
#
#                               Sig  Tabular  \
# BeijingIntAirportPM25Quality  6.0      1.0
# WaveDataTension               5.0      1.0
# ParkingBirmingham             4.0      5.0
# DhakaHourlyAirQuality         6.0      2.0
# MagnesiumConcentration        6.0      1.0
# PotassiumConcentration        6.0      3.0
# PhosphorusConcentration       6.0      2.0
# IEEEPPG                       7.0      3.0
#
#                               Time Inhomogenous Randomized Signature
# BeijingIntAirportPM25Quality                                     5.0
# WaveDataTension                                                  2.0
# ParkingBirmingham                                                3.0
# DhakaHourlyAirQuality                                            4.0
# MagnesiumConcentration                                           4.0
# PotassiumConcentration                                           5.0
# PhosphorusConcentration                                          4.0
# IEEEPPG                                                          4.0

# %%
df_med["RMSE_test"]
# Out:
#                               MultiRocket  Random Guesser  \
# BeijingIntAirportPM25Quality     0.762462        0.998072
# WaveDataTension                  1.016923        1.088821
# ParkingBirmingham                0.621193        1.067190
# DhakaHourlyAirQuality            0.092696        1.040910
# MagnesiumConcentration           0.375519        0.985363
# PotassiumConcentration           0.587728        0.739649
# PhosphorusConcentration          0.636007        0.937045
# IEEEPPG                          1.232147        1.540215
#
#                               Randomized Signature  Sampled Controlled ResNet  \
# BeijingIntAirportPM25Quality              0.837342                   0.882803
# WaveDataTension                           0.919409                   0.883040
# ParkingBirmingham                         1.020380                   0.765438
# DhakaHourlyAirQuality                     0.321173                   0.224035
# MagnesiumConcentration                    0.665889                   0.531011
# PotassiumConcentration                    0.671364                   0.623145
# PhosphorusConcentration                   0.885559                   0.835389
# IEEEPPG                                   1.303069                   1.519105
#
#                                     Sig   Tabular  \
# BeijingIntAirportPM25Quality   0.893760  0.748680
# WaveDataTension                0.989143  0.821681
# ParkingBirmingham              0.919772  1.000532
# DhakaHourlyAirQuality          0.435960  0.198016
# MagnesiumConcentration         0.849769  0.356027
# PotassiumConcentration         0.698375  0.647635
# PhosphorusConcentration        0.910623  0.820897
# IEEEPPG                       29.344443  1.314504
#
#                               Time Inhomogenous Randomized Signature
# BeijingIntAirportPM25Quality                                0.888635
# WaveDataTension                                             0.872344
# ParkingBirmingham                                           0.879767
# DhakaHourlyAirQuality                                       0.275619
# MagnesiumConcentration                                      0.544208
# PotassiumConcentration                                      0.676318
# PhosphorusConcentration                                     0.847630
# IEEEPPG                                                     1.464025

# %%
df_med2 = pd.read_pickle("TSER_results_medium2.pkl")
df_med2["RMSE_test"]
# Out:
#                               MultiRocket  Random Guesser  \
# BeijingIntAirportPM25Quality     0.734932        0.989172
# WaveDataTension                  1.023092        1.074938
# ParkingBirmingham                0.608596        1.070208
# DhakaHourlyAirQuality            0.087498        1.031408
# MagnesiumConcentration           0.367341        0.997610
# PotassiumConcentration           0.582014        0.750103
# PhosphorusConcentration          0.640510        0.934019
# IEEEPPG                          1.243750        1.550787
#
#                               Randomized Signature  Sampled Controlled ResNet  \
# BeijingIntAirportPM25Quality              0.868496                   0.696935
# WaveDataTension                           0.985453                   0.886434
# ParkingBirmingham                         1.040897                   0.773245
# DhakaHourlyAirQuality                     0.415107                   0.124193
# MagnesiumConcentration                    0.877982                   0.529521
# PotassiumConcentration                    0.703472                   0.635628
# PhosphorusConcentration                   0.909306                   0.850401
# IEEEPPG                                   1.483619                   1.270224
#
#                                     Sig   Tabular  \
# BeijingIntAirportPM25Quality   0.893760  0.748680
# WaveDataTension                0.989143  0.821681
# ParkingBirmingham              0.919772  1.000532
# DhakaHourlyAirQuality          0.435960  0.198016
# MagnesiumConcentration         0.849769  0.356027
# PotassiumConcentration         0.698375  0.647635
# PhosphorusConcentration        0.910623  0.820897
# IEEEPPG                       29.344443  1.314504
#
#                               Time Inhomogenous Randomized Signature
# BeijingIntAirportPM25Quality                                0.845856
# WaveDataTension                                             0.839360
# ParkingBirmingham                                           0.980735
# DhakaHourlyAirQuality                                       0.195287
# MagnesiumConcentration                                      0.494900
# PotassiumConcentration                                      0.649952
# PhosphorusConcentration                                     0.841762
# IEEEPPG                                                     1.518755
