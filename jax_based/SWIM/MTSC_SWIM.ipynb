# %%
from typing import Tuple, List, Union, Any, Optional, Dict, Literal, Callable
import time
import collections
import os
import sys
sys.path.append(os.path.dirname(os.getcwd()))
sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))

from tqdm import tqdm
import numpy as np
import jax
import jax.numpy as jnp
import jax.lax as lax
from jaxtyping import Array, Float, Int, PRNGKeyArray
import aeon
import pandas as pd
from preprocessing.timeseries_augmentation import normalize_mean_std_traindata, normalize_streams, augment_time, add_basepoint_zero
from sklearn.metrics import accuracy_score, f1_score
from aeon.datasets.tsc_datasets import multivariate_equal_length
from aeon.datasets import load_regression, load_classification
from sklearn.linear_model import RidgeClassifierCV

from features.sig import SigTransform, LogSigTransform
from features.base import TimeseriesFeatureTransformer, TabularTimeseriesFeatures, RandomGuesser
from features.sig_neural import RandomizedSignature, TimeInhomogenousRandomizedSignature
from features.SWIM_controlled_resnet import SampledControlledResNet
from features.rocket_wrappers import RocketWrapper
from utils.utils import print_name, print_shape

jax.config.update('jax_platform_name', 'cpu') # Used to set the platform (cpu, gpu, etc.)
np.set_printoptions(precision=3, threshold=10) # Print options
# Out:
# 2024-09-23 16:01:23.471521: W external/xla/xla/service/gpu/nvptx_compiler.cc:718] The NVIDIA driver's CUDA version is 12.4 which is older than the ptxas CUDA version (12.5.82). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
# /home/nikita/Code/zephyrox/.conda/lib/python3.10/site-packages/aeon/base/__init__.py:24: FutureWarning: The aeon package will soon be releasing v1.0.0 with the removal of legacy modules and interfaces such as BaseTransformer and BaseForecaster. This will contain breaking changes. See aeon-toolkit.org for more information. Set aeon.AEON_DEPRECATION_WARNING or the AEON_DEPRECATION_WARNING environmental variable to 'False' to disable this warning.
#   warnings.warn(

# %% [markdown]
# # Download dataset code

# %%
def get_aeon_dataset(
        dataset_name:str,
        normalize:bool = True,
        TSER_or_MTSC:str = "MTSC",
        extract_path = "/home/nikita/hdd/Data/",
        max_T:int = 1000,
        ):
    """Loads a dataset from the UCR/UEA archive using
    the aeon library.

    Args:
        dataset_name (str): Name of the dataset
        normalize (bool): Whether to apply z-score normalization based on
            the train set data.
        TSER_or_TSC (str): Whether to load a TSER or MTSC dataset.
        extract_path (str): Path to the directory where the datasets are stored.
            Note that the datasets are stored in a subdirectory called "TSER" or "TSC".
        max_T (int): Maximum length of the time series. If the time series is longer
            than this value, it will be average pooled down.

    Returns:
        Tuple: 4-tuple of the form (X_train, y_train, X_test, y_test)
    """
    if TSER_or_MTSC == "TSER":
        load_fun = load_regression 
    elif TSER_or_MTSC == "MTSC":
        load_fun = load_classification
    else:
        raise ValueError("TSER_or_TSC must be either 'TSER' or 'MTSC'")
    
    #download
    X_train, y_train = load_fun(dataset_name, split="train", extract_path=extract_path + TSER_or_MTSC + "/")
    X_test, y_test = load_fun(dataset_name, split="test", extract_path=extract_path + TSER_or_MTSC + "/")

    if load_fun == load_classification:
        # y is a list of string labels. I want to number these from 0 to n_labels
        y_train = np.unique(y_train, return_inverse=True)[1]
        y_test = np.unique(y_test, return_inverse=True)[1]

    #to jax array NOTE hardcoded no gradients
    X_train = lax.stop_gradient(jnp.array(X_train).transpose(0,2,1))
    X_test = lax.stop_gradient(jnp.array(X_test).transpose(0,2,1))
    y_train = lax.stop_gradient(jnp.array(y_train))
    y_test = lax.stop_gradient(jnp.array(y_test))

    #normalize
    if normalize:
        X_train, X_test = normalize_streams(X_train, X_test, max_T)
        c = 5.0
        X_train = X_train.clip(-c, c)
        X_test = X_test.clip(-c, c)

    return X_train, y_train, X_test, y_test


# df = []
# for dataset_name in list(multivariate_equal_length):
#     print(dataset_name)
#     X_train, y_train, X_test, y_test = get_aeon_dataset(dataset_name)

#     N1, T, D = X_train.shape
#     N2, T, D = X_test.shape
#     metadata_row = {
#                     "Dataset": dataset_name,
#                     "N_train": N1,
#                     "N_test": N2,
#                     "T": T,
#                     "D": D,
#                     "y_train_shape": y_train.shape,
#                     "n_labels": len(np.unique(y_train)),}
#     df.append(metadata_row)
# df = pd.DataFrame(df).set_index("Dataset")
# df.to_pickle("MTSC_dataset_metadata.pkl")

# %%
df_meta = pd.read_pickle("MTSC_dataset_metadata.pkl")
df_meta.head()
# Out:
#                      N_train  N_test     T    D y_train_shape  n_labels
# Dataset
# PhonemeSpectra          3315    3353   217   11     (3315, 1)        39
# UWaveGestureLibrary      120     320   315    3      (120, 1)         8
# AtrialFibrillation        15      15   640    2       (15, 1)         3
# FaceDetection           5890    3524    62  144     (5890, 1)         2
# MotorImagery             278     100  1000   64      (278, 1)         2

# %%
large_datasets = df_meta.query("N_train >= 2000").sort_values("N_train")
print(large_datasets)
large_datasets = list(large_datasets.index)
# Out:
#                 N_train  N_test    T    D y_train_shape  n_labels
# Dataset
# LSST               2459    2466   36    6     (2459, 1)        14
# PhonemeSpectra     3315    3353  217   11     (3315, 1)        39
# FaceDetection      5890    3524   62  144     (5890, 1)         2
# PenDigits          7494    3498    8    2     (7494, 1)        10

# %%
small_datasets = df_meta.query("100 <= N_train <= 1000 & D < 100").sort_values("N_train")
print(small_datasets)
small_datasets = list(small_datasets.index)
# Out:
#                            N_train  N_test     T   D y_train_shape  n_labels
# Dataset
# Cricket                        108      72   599   6      (108, 1)        12
# UWaveGestureLibrary            120     320   315   3      (120, 1)         8
# EigenWorms                     128     131  1000   6      (128, 1)         5
# Epilepsy                       137     138   206   3      (137, 1)         4
# Handwriting                    150     850   152   3      (150, 1)        26
# RacketSports                   151     152    30   6      (151, 1)         4
# HandMovementDirection          160      74   400  10      (160, 1)         4
# Libras                         180     180    45   2      (180, 1)        15
# NATOPS                         180     180    51  24      (180, 1)         6
# SelfRegulationSCP2             200     180   576   7      (200, 1)         2
# Heartbeat                      204     205   405  61      (204, 1)         2
# EthanolConcentration           261     263   876   3      (261, 1)         4
# SelfRegulationSCP1             268     293   896   6      (268, 1)         2
# ArticularyWordRecognition      275     300   144   9      (275, 1)        25
# MotorImagery                   278     100  1000  64      (278, 1)         2
# FingerMovements                316     100    50  28      (316, 1)         2

# %% [markdown]
# # Experiment code

# %%
def run_1model_1dataset(
        model: TimeseriesFeatureTransformer,
        X_train: Float[Array, "N1  T  D"],
        y_train: Float[Array, "N1  1"],
        X_test: Float[Array, "N2  T  D"],
        y_test: Float[Array, "N2"],
        normalize_features: bool,
        apply_augment_time: bool,
        apply_basepoint: bool,
        ):

    if apply_basepoint:
        X_train = add_basepoint_zero(X_train)
        X_test = add_basepoint_zero(X_test)
    if apply_augment_time:
        X_train = augment_time(X_train)
        X_test  = augment_time(X_test)

    #fit feature model
    t0 = time.time()
    model.fit(X_train, y_train)

    #obtain features
    t1 = time.time()
    feat_train = model.transform(X_train)
    feat_test = model.transform(X_test)
    print(model)
    print_name(feat_train)

    if normalize_features:
        feat_train, feat_test = normalize_mean_std_traindata(feat_train, feat_test)

    #fit ridge regression
    t2 = time.time()
    y_train = np.array(y_train)
    y_test = np.array(y_test)
    feat_train = np.array(feat_train)
    feat_test = np.array(feat_test)
    ridge = RidgeClassifierCV(alphas=np.logspace(-3, 3, 30))
    ridge.fit(feat_train, y_train)

    # predict
    pred_test = ridge.predict(feat_test)
    pred_train = ridge.predict(feat_train)
    test_acc = np.mean(pred_test == y_test)
    train_acc = np.mean(pred_train == y_train)
    alpha = ridge.alpha_
    t3 = time.time()
    # print("Model:", model)
    # print("train_RMSE:", train_rmse)
    # print("test_RMSE:", test_rmse)
    # print("alpha (regularization):", alpha, "\n")
    t_fit_feat = t1 - t0
    t_trans_feat = t2 - t1
    t_ridge = t3 - t2
    return train_acc, test_acc, alpha, t_fit_feat, t_trans_feat, t_ridge



def run_allmodels_1dataset(
        X_train: Float[Array, "N1  T  D"],
        y_train: Float[Array, "N1  1"],
        X_test: Float[Array, "N2  T  D"],
        y_test: Float[Array, "N2"],
        normalize_features: bool,
        apply_augment_time: bool,
        apply_basepoint: bool,
        ):

    prng_key = jax.random.PRNGKey(999)
    max_batch = 1000
    n_features = 100
    models = [
        ["Random Guesser", RandomGuesser(prng_key, 100, max_batch)],
        ["Tabular", TabularTimeseriesFeatures(max_batch)],
        ["Sig", SigTransform(2, max_batch)],
        #["Log Sig", LogSigTransform(2, max_batch)],
        ["Randomized Signature", RandomizedSignature(
            prng_key,
            n_features,
            max_batch,
            )],
        ["Time Inhomogenous Randomized Signature", TimeInhomogenousRandomizedSignature(
            prng_key,
            n_features,
            max_batch,
            )],
        ["Sampled Controlled ResNet", SampledControlledResNet(
            prng_key,
            n_features,
            jnp.tanh,
            max_batch,
            transform_label_to_onehot = True,
            )],
        ["Rocket", RocketWrapper(
            20000,
            10000000,
            )],
        ]
    
    results = []
    model_names = [name for name, _ in models]
    for name, model in models:
        res = run_1model_1dataset(
            model, X_train, y_train, X_test, y_test, 
            normalize_features, apply_augment_time, apply_basepoint
            )
        results.append(res)
    return model_names, results



def run_all_experiments(
        datasets: List[str],
        name_save: str,
        normalize_X: bool = True,
        normalize_features: bool = False,
        apply_augment_time: bool = False,
        apply_basepoint: bool = True,
        max_T = 100,
        ):
    # Run experiments
    experiments = {}
    failed = {}
    for dataset_name in datasets:
        t0 = time.time()
        # try:
        print(dataset_name)
        X_train, y_train, X_test, y_test = get_aeon_dataset(dataset_name, normalize_X, max_T=max_T)
        X_train, X_test = normalize_streams(X_train, X_test, max_T=max_T)
        print(X_train.shape, X_test.shape)
        results = run_allmodels_1dataset(
            X_train, y_train, X_test, y_test, 
            normalize_features, apply_augment_time, apply_basepoint,
            )
        jax.clear_caches()
        experiments[dataset_name] = results
        # except Exception as e:
        #     print(f"Error: {e}")
        #     failed[dataset_name] = e
        print(dataset_name, "Elapsed time", time.time()-t0)
    
    # Save results
    # Assuming experiments is a dict where keys are dataset names and values are tuples (model_names, results)
    attributes = ["acc_train", "acc_test", "alpha", "t_fit_feat", "t_trans_feat", "t_ridge"]
    data_list = []
    # Process the data
    for dataset_name, (model_names, results) in experiments.items():
        dataset_data = {}
        for attr_idx, attribute in enumerate(attributes):
            for model_idx, model_name in enumerate(model_names):
                dataset_data[(attribute, model_name)] = results[model_idx][attr_idx]
        data_list.append(pd.DataFrame(dataset_data, index=[dataset_name]))

    # Combine all datasets into a single DataFrame
    df = pd.concat(data_list)
    df = df.sort_index(axis=1)
    print(df)
    df.to_pickle(f"TSER_results_{name_save}.pkl")
    return df

# %%
df = run_all_experiments(small_datasets, "small", max_T=100)
# Out:
# Cricket
# (108, 100, 6) (72, 100, 6)
# RandomGuesser(max_batch=1000, n_features=100,
#               seed=Array([  0, 999], dtype=uint32))
# (108, 100) feat_train
# [[ 0.3    0.025  3.56  ...  1.641 -0.29   1.591]
#  [ 1.421 -0.594  1.536 ...  0.588 -1.833  0.743]
#  [-0.076 -1.144 -1.099 ... -0.504  1.089  0.821]
#  ...
#  [-0.313  2.361 -0.116 ... -1.376 -0.888 -0.256]
#  [ 0.589  0.727  0.973 ... -1.807  0.499  0.449]
#  [ 2.993  0.378 -0.269 ...  0.392  0.444 -0.793]]
#
# TabularTimeseriesFeatures(max_batch=1000)
# (108, 606) feat_train
# [[ 0.     0.     0.    ... -0.838  0.628 -0.295]
#  [ 0.     0.     0.    ...  0.594 -1.081 -0.031]
#  [ 0.     0.     0.    ... -0.298  0.631  0.092]
#  ...
#  [ 0.     0.     0.    ...  0.09   0.699 -0.405]
#  [ 0.     0.     0.    ...  0.128  0.986 -0.469]
#  [ 0.     0.     0.    ... -0.118  1.329 -0.491]]
#
# SigTransform(max_batch=1000, trunc_level=2)
# (108, 42) feat_train
# [[-9.203e-01 -5.993e-01 -3.394e-01 ... -5.215e-01 -5.750e+00  4.353e-02]
#  [-3.035e-01  4.650e-01 -4.776e-02 ... -1.017e+00  2.449e+00  4.832e-04]
#  [-6.472e-01 -5.232e-01 -3.589e-01 ... -1.133e+00 -4.226e+00  4.262e-03]
#  ...
#  [-3.738e-01 -1.378e+00 -3.856e-01 ... -1.601e+00 -2.066e+00  8.196e-02]
#  [-3.961e-01 -1.375e+00 -5.099e-01 ... -5.306e+00 -5.451e-01  1.101e-01]
#  [-5.170e-01 -1.355e+00 -6.840e-01 ... -1.519e+00 -2.464e+00  1.203e-01]]
#
# RandomizedSignature(max_batch=1000, n_features=100,
#                     seed=Array([  0, 999], dtype=uint32))
# (108, 100) feat_train
# [[-0.533  0.359  0.135 ... -0.82   1.227 -0.154]
#  [-0.537  0.356  0.139 ... -0.824  1.225 -0.152]
#  [-0.534  0.358  0.135 ... -0.821  1.227 -0.154]
#  ...
#  [-0.534  0.358  0.136 ... -0.821  1.225 -0.153]
#  [-0.534  0.358  0.135 ... -0.821  1.225 -0.153]
#  [-0.533  0.359  0.134 ... -0.82   1.225 -0.153]]
#
# TimeInhomogenousRandomizedSignature(max_batch=1000, n_features=100,
#                                     seed=Array([  0, 999], dtype=uint32))
# (108, 100) feat_train
# [[-0.539  0.356  0.135 ... -0.812  1.23  -0.158]
#  [-0.534  0.369  0.139 ... -0.797  1.233 -0.156]
#  [-0.538  0.373  0.138 ... -0.818  1.228 -0.157]
#  ...
#  [-0.533  0.355  0.135 ... -0.813  1.231 -0.16 ]
#  [-0.535  0.349  0.125 ... -0.813  1.234 -0.153]
#  [-0.539  0.365  0.138 ... -0.844  1.22  -0.138]]
#
# SampledControlledResNet(max_batch=1000, n_features=100,
#                         seed=Array([  0, 999], dtype=uint32),
#                         transform_label_to_onehot=True)
# (108, 100) feat_train
# [[-0.535 -0.747  0.74  ...  0.811  0.221 -0.883]
#  [-0.327 -0.915  0.992 ... -0.791  0.979 -0.955]
#  [-0.6   -0.972  0.368 ...  0.134 -0.372 -0.512]
#  ...
#  [-0.526  0.038  0.995 ...  0.998 -0.587 -0.935]
#  [ 0.634 -0.075  0.998 ...  0.928  0.577 -0.237]
#  [ 0.521  0.931  0.245 ...  0.645  0.479  0.616]]
#
# MultiRocketWrapper(max_batch=10000000, n_features=50000)
# (108, 49728) feat_train
# [[2.574e-01 9.208e-01 2.970e-02 ... 1.000e+00 4.950e+01 2.991e+01]
#  [1.782e-01 9.208e-01 4.950e-02 ... 5.000e-01 4.950e+01 1.720e+01]
#  [1.485e-01 9.208e-01 3.960e-02 ... 2.000e+00 4.950e+01 2.867e+01]
#  ...
#  [2.475e-01 9.010e-01 8.911e-02 ... 2.000e+00 4.950e+01 2.850e+01]
#  [2.574e-01 8.218e-01 1.089e-01 ... 3.000e+00 4.950e+01 3.739e+01]
#  [2.178e-01 9.109e-01 3.960e-02 ... 2.000e+00 4.950e+01 3.730e+01]]
#
# Cricket Elapsed time 10.34796929359436
# UWaveGestureLibrary
# (120, 79, 3) (320, 79, 3)
# RandomGuesser(max_batch=1000, n_features=100,
#               seed=Array([  0, 999], dtype=uint32))
# (120, 100) feat_train
# [[-0.892 -1.044  0.572 ...  0.659  1.09  -1.69 ]
#  [-1.585  0.203 -0.639 ...  1.202 -0.903  0.26 ]
#  [ 0.083 -0.074  1.165 ...  0.444  0.444  0.013]
#  ...
#  [-0.699 -1.186 -1.218 ...  1.21   0.027 -1.794]
#  [ 0.35   0.441  1.299 ...  2.379  0.995  0.892]
#  [-0.618  0.447  0.189 ... -1.801 -0.964 -0.139]]
#
# TabularTimeseriesFeatures(max_batch=1000)
# (120, 240) feat_train
# [[ 0.     0.     0.    ... -1.543  1.096  1.054]
#  [ 0.     0.     0.    ... -0.322  1.162  0.442]
#  [ 0.     0.     0.    ...  0.199 -0.102  0.7  ]
#  ...
#  [ 0.     0.     0.    ...  0.095  0.094  0.469]
#  [ 0.     0.     0.    ...  0.008  0.069 -0.079]
#  [ 0.     0.     0.    ...  0.847  0.416  0.438]]
#
# SigTransform(max_batch=1000, trunc_level=2)
# (120, 12) feat_train
# [[-1.543e+00  1.096e+00  1.054e+00 ...  1.666e-01 -5.025e+00  5.551e-01]
#  [-3.217e-01  1.162e+00  4.423e-01 ...  5.449e-01 -8.724e-01  9.783e-02]
#  [ 1.986e-01 -1.020e-01  7.004e-01 ...  6.884e-01 -5.694e+00  2.453e-01]
#  ...
#  [ 9.530e-02  9.418e-02  4.695e-01 ...  9.276e+00  9.585e+00  1.102e-01]
#  [ 8.283e-03  6.857e-02 -7.921e-02 ...  6.358e+00  4.663e+00  3.137e-03]
#  [ 8.473e-01  4.162e-01  4.384e-01 ...  5.414e+00  4.528e+00  9.612e-02]]
#
# RandomizedSignature(max_batch=1000, n_features=100,
#                     seed=Array([  0, 999], dtype=uint32))
# (120, 100) feat_train
# [[-0.547  0.352  0.128 ... -0.82   1.225 -0.158]
#  [-0.541  0.354  0.135 ... -0.818  1.228 -0.16 ]
#  [-0.537  0.36   0.135 ... -0.82   1.23  -0.157]
#  ...
#  [-0.537  0.358  0.135 ... -0.821  1.228 -0.157]
#  [-0.535  0.358  0.137 ... -0.823  1.226 -0.154]
#  [-0.535  0.359  0.139 ... -0.817  1.232 -0.161]]
#
# TimeInhomogenousRandomizedSignature(max_batch=1000, n_features=100,
#                                     seed=Array([  0, 999], dtype=uint32))
# (120, 100) feat_train
# [[-0.539  0.342  0.12  ... -0.823  1.221 -0.156]
#  [-0.53   0.353  0.138 ... -0.828  1.214 -0.168]
#  [-0.529  0.345  0.136 ... -0.82   1.235 -0.142]
#  ...
#  [-0.535  0.372  0.158 ... -0.836  1.221 -0.154]
#  [-0.525  0.357  0.137 ... -0.825  1.242 -0.157]
#  [-0.534  0.364  0.132 ... -0.826  1.228 -0.142]]
#
# SampledControlledResNet(max_batch=1000, n_features=100,
#                         seed=Array([  0, 999], dtype=uint32),
#                         transform_label_to_onehot=True)
# (120, 100) feat_train
# [[-0.929 -0.947  0.157 ... -0.985  0.943 -0.926]
#  [-0.958 -0.949  0.949 ... -0.624 -0.12  -0.94 ]
#  [-0.166 -0.856 -0.343 ...  0.818 -0.773  0.678]
#  ...
#  [-0.141 -0.29   0.843 ... -0.958  0.487 -1.001]
#  [-0.778  0.659 -0.51  ...  0.912 -0.972  0.987]
#  [-0.934  0.97  -0.496 ... -0.484 -0.95   0.997]]
#
# MultiRocketWrapper(max_batch=10000000, n_features=50000)
# (120, 49728) feat_train
# [[ 0.312  0.863  0.138 ...  3.     3.    -1.   ]
#  [ 0.325  0.825  0.125 ...  5.5    3.    -1.   ]
#  [ 0.25   0.85   0.175 ...  5.     3.    -1.   ]
#  ...
#  [ 0.3    0.75   0.2   ...  3.     3.     2.333]
#  [ 0.338  0.712  0.275 ...  3.75   3.     3.667]
#  [ 0.338  0.788  0.287 ...  3.     3.     3.   ]]
#
# UWaveGestureLibrary Elapsed time 8.606704711914062
# EigenWorms
# (128, 100, 6) (131, 100, 6)
# RandomGuesser(max_batch=1000, n_features=100,
#               seed=Array([  0, 999], dtype=uint32))
# (128, 100) feat_train
# [[ 0.386 -0.679  0.391 ... -1.007  1.32  -0.702]
#  [ 0.259  1.533 -0.703 ...  0.195  0.433  0.535]
#  [-0.802  0.069  0.984 ...  0.897 -0.25  -1.379]
#  ...
#  [-0.058 -1.283  1.322 ...  1.218  0.382 -3.3  ]
#  [-0.363  0.15   0.119 ... -0.371 -0.562 -0.252]
#  [ 1.861  0.524 -0.198 ... -0.079 -0.817 -1.765]]
#
# TabularTimeseriesFeatures(max_batch=1000)
# (128, 606) feat_train
# [[ 0.     0.     0.    ...  0.03   0.081  0.12 ]
#  [ 0.     0.     0.    ... -0.874  0.033  0.121]
#  [ 0.     0.     0.    ... -0.36   0.004  0.087]
#  ...
#  [ 0.     0.     0.    ... -0.706  0.19  -0.078]
#  [ 0.     0.     0.    ... -0.563  0.535 -0.325]
#  [ 0.     0.     0.    ...  0.038 -0.324  0.292]]
#
# SigTransform(max_batch=1000, trunc_level=2)
# (128, 42) feat_train
# [[-1.079e-01 -2.439e-01 -4.772e-02 ... -1.570e+00  3.696e+00  2.931e-03]
#  [ 4.227e-03  8.664e-02 -1.006e-03 ...  6.026e+00  8.054e+00  2.959e-03]
#  [-7.223e-02 -1.076e-01  1.113e-01 ... -8.452e-01  1.156e+00  1.527e-03]
#  ...
#  [-1.003e-01 -7.539e-03  2.522e-01 ...  1.031e+01  1.585e+01  1.295e-03]
#  [-5.628e-02  6.007e-02  1.077e-01 ... -4.208e+00  5.788e+00  2.211e-02]
#  [ 3.422e-02 -9.088e-02  1.355e-01 ... -4.987e+00  2.179e+01  1.745e-02]]
#
# RandomizedSignature(max_batch=1000, n_features=100,
#                     seed=Array([  0, 999], dtype=uint32))
# (128, 100) feat_train
# [[-0.535  0.358  0.137 ... -0.822  1.226 -0.154]
#  [-0.534  0.359  0.136 ... -0.822  1.228 -0.155]
#  [-0.535  0.358  0.137 ... -0.823  1.227 -0.155]
#  ...
#  [-0.534  0.359  0.137 ... -0.822  1.227 -0.155]
#  [-0.534  0.36   0.137 ... -0.823  1.227 -0.155]
#  [-0.535  0.357  0.137 ... -0.823  1.226 -0.154]]
#
# TimeInhomogenousRandomizedSignature(max_batch=1000, n_features=100,
#                                     seed=Array([  0, 999], dtype=uint32))
# (128, 100) feat_train
# [[-0.556  0.359  0.135 ... -0.845  1.286 -0.139]
#  [-0.563  0.374  0.122 ... -0.784  1.188 -0.192]
#  [-0.572  0.338  0.114 ... -0.821  1.21  -0.165]
#  ...
#  [-0.51   0.382  0.089 ... -0.833  1.231 -0.144]
#  [-0.486  0.412  0.107 ... -0.848  1.225 -0.123]
#  [-0.529  0.389  0.136 ... -0.878  1.195 -0.146]]
#
# SampledControlledResNet(max_batch=1000, n_features=100,
#                         seed=Array([  0, 999], dtype=uint32),
#                         transform_label_to_onehot=True)
# (128, 100) feat_train
# [[ 0.406 -0.857  0.975 ...  0.462  0.281 -0.641]
#  [-0.75  -0.915  0.938 ... -0.274  0.876 -0.611]
#  [-0.857 -0.232  0.853 ... -0.313 -0.694  0.425]
#  ...
#  [-0.974  0.441  0.98  ... -0.699  0.636 -0.665]
#  [-0.877 -0.93   0.876 ... -1.069 -1.006  1.025]
#  [-0.173 -0.652  0.988 ...  0.684  0.918 -0.844]]
#
# MultiRocketWrapper(max_batch=10000000, n_features=50000)
# (128, 49728) feat_train
# [[2.970e-01 8.317e-01 2.970e-02 ... 1.500e+00 5.034e+01 4.994e+01]
#  [2.871e-01 7.624e-01 7.921e-02 ... 1.000e+00 5.046e+01 4.462e+01]
#  [2.079e-01 8.614e-01 4.950e-02 ... 1.000e+00 5.196e+01 4.071e+01]
#  ...
#  [3.564e-01 7.624e-01 7.921e-02 ... 2.000e+00 5.147e+01 4.673e+01]
#  [4.059e-01 6.535e-01 1.980e-01 ... 2.000e+00 5.317e+01 4.708e+01]
#  [4.356e-01 6.733e-01 1.980e-01 ... 1.333e+00 5.248e+01 4.747e+01]]
#
# EigenWorms Elapsed time 14.918529510498047
# Epilepsy
# (137, 69, 3) (138, 69, 3)
# RandomGuesser(max_batch=1000, n_features=100,
#               seed=Array([  0, 999], dtype=uint32))
# (137, 100) feat_train
# [[-1.284  1.327  1.637 ...  1.231  0.13  -0.78 ]
#  [-0.156 -0.102  0.646 ... -0.074 -0.458 -0.061]
#  [-1.171  0.27  -0.581 ... -2.011  0.773  0.977]
#  ...
#  [ 2.87   1.531  0.896 ...  1.237  0.457 -0.31 ]
#  [ 0.023 -0.723  0.282 ...  0.811  0.038 -1.563]
#  [-0.963  0.267  0.197 ...  0.09   0.824 -0.078]]
#
# TabularTimeseriesFeatures(max_batch=1000)
# (137, 210) feat_train
# [[ 0.     0.     0.    ...  0.679 -1.089  1.428]
#  [ 0.     0.     0.    ... -0.67   1.354 -1.313]
#  [ 0.     0.     0.    ...  0.583  1.445  0.342]
#  ...
#  [ 0.     0.     0.    ... -0.983  0.717  0.281]
#  [ 0.     0.     0.    ... -0.429 -0.173 -1.912]
#  [ 0.     0.     0.    ...  0.986 -0.693  0.017]]
#
# SigTransform(max_batch=1000, trunc_level=2)
# (137, 12) feat_train
# [[ 6.792e-01 -1.089e+00  1.428e+00 ...  2.759e-01 -1.596e+00  1.019e+00]
#  [-6.702e-01  1.354e+00 -1.313e+00 ...  3.198e-01 -1.635e+00  8.617e-01]
#  [ 5.829e-01  1.445e+00  3.416e-01 ...  3.030e-01  1.459e+00  5.835e-02]
#  ...
#  [-9.834e-01  7.175e-01  2.807e-01 ... -1.006e+00 -9.992e-01  3.940e-02]
#  [-4.292e-01 -1.727e-01 -1.912e+00 ... -2.868e+00  5.996e-01  1.827e+00]
#  [ 9.865e-01 -6.925e-01  1.682e-02 ...  3.809e-02 -6.251e-01  1.414e-04]]
#
# RandomizedSignature(max_batch=1000, n_features=100,
#                     seed=Array([  0, 999], dtype=uint32))
# (137, 100) feat_train
# [[-0.535  0.366  0.132 ... -0.818  1.234 -0.159]
#  [-0.537  0.35   0.141 ... -0.826  1.22  -0.152]
#  [-0.539  0.355  0.14  ... -0.813  1.232 -0.165]
#  ...
#  [-0.543  0.352  0.132 ... -0.823  1.224 -0.155]
#  [-0.529  0.357  0.143 ... -0.835  1.218 -0.143]
#  [-0.529  0.364  0.141 ... -0.822  1.23  -0.155]]
#
# TimeInhomogenousRandomizedSignature(max_batch=1000, n_features=100,
#                                     seed=Array([  0, 999], dtype=uint32))
# (137, 100) feat_train
# [[-0.503  0.331  0.092 ... -0.821  1.157 -0.145]
#  [-0.519  0.359  0.141 ... -0.844  1.225 -0.204]
#  [-0.539  0.374  0.204 ... -0.834  1.221 -0.133]
#  ...
#  [-0.597  0.378  0.226 ... -0.872  1.211 -0.099]
#  [-0.553  0.284  0.164 ... -0.739  1.257 -0.172]
#  [-0.521  0.433  0.148 ... -0.803  1.225 -0.144]]
#
# SampledControlledResNet(max_batch=1000, n_features=100,
#                         seed=Array([  0, 999], dtype=uint32),
#                         transform_label_to_onehot=True)
# (137, 100) feat_train
# [[-0.972  0.388  0.985 ...  0.919  0.103  0.914]
#  [ 0.045 -0.611  0.971 ... -0.539 -0.345  0.297]
#  [-0.658  0.496  0.461 ...  0.741 -0.836  0.895]
#  ...
#  [ 0.416  0.061 -0.867 ...  0.147  0.412  0.466]
#  [ 0.272 -1.02   0.983 ... -0.911  0.78  -0.975]
#  [-0.907 -0.965  0.86  ... -0.453  0.598  0.377]]
#
# MultiRocketWrapper(max_batch=10000000, n_features=50000)
# (137, 49728) feat_train
# [[ 0.471  0.657  0.3   ...  1.667 32.641 32.156]
#  [ 0.443  0.957  0.043 ...  1.5   36.119 34.097]
#  [ 0.371  0.929  0.057 ...  2.    34.14  32.303]
#  ...
#  [ 0.414  0.914  0.    ...  2.    33.128 31.645]
#  [ 0.486  0.986  0.071 ...  1.    34.875 33.588]
#  [ 0.314  0.971  0.043 ...  2.    35.    32.688]]
#
# Epilepsy Elapsed time 7.029677629470825
# Handwriting
# (150, 76, 3) (850, 76, 3)
# RandomGuesser(max_batch=1000, n_features=100,
#               seed=Array([  0, 999], dtype=uint32))
# (150, 100) feat_train
# [[ 0.331  0.292 -0.736 ...  0.528 -0.281 -0.729]
#  [-0.926  1.413  0.695 ... -0.749  0.552  0.771]
#  [ 0.029  0.604 -0.872 ...  0.122 -0.376  0.517]
#  ...
#  [-0.407 -1.023 -0.519 ... -0.365  0.609 -1.958]
#  [ 0.472 -1.191  1.638 ...  1.032 -1.885  0.346]
#  [-0.167 -0.328  0.011 ...  0.019  0.348  0.01 ]]
#
# TabularTimeseriesFeatures(max_batch=1000)
# (150, 231) feat_train
# [[ 0.     0.     0.    ... -0.367  1.513 -3.918]
#  [ 0.     0.     0.    ... -0.703 -2.207  0.587]
#  [ 0.     0.     0.    ... -1.209 -1.72  -0.676]
#  ...
#  [ 0.     0.     0.    ...  1.499  1.047  0.259]
#  [ 0.     0.     0.    ...  0.595  1.168 -0.497]
#  [ 0.     0.     0.    ... -0.732  0.019  0.135]]
#
# SigTransform(max_batch=1000, trunc_level=2)
# (150, 12) feat_train
# [[-3.669e-01  1.513e+00 -3.918e+00 ... -2.004e+00 -4.604e+00  7.674e+00]
#  [-7.025e-01 -2.208e+00  5.865e-01 ...  2.393e+00 -5.032e+00  1.720e-01]
#  [-1.209e+00 -1.720e+00 -6.756e-01 ... -7.657e-01 -3.186e+00  2.282e-01]
#  ...
#  [ 1.499e+00  1.047e+00  2.587e-01 ...  3.683e+00 -8.108e-01  3.346e-02]
#  [ 5.946e-01  1.168e+00 -4.966e-01 ... -1.213e+01  9.586e+00  1.233e-01]
#  [-7.324e-01  1.886e-02  1.349e-01 ... -1.387e+01  1.495e+00  9.101e-03]]
#
# RandomizedSignature(max_batch=1000, n_features=100,
#                     seed=Array([  0, 999], dtype=uint32))
# (150, 100) feat_train
# [[-0.526  0.349  0.153 ... -0.835  1.214 -0.143]
#  [-0.533  0.365  0.129 ... -0.832  1.224 -0.145]
#  [-0.532  0.361  0.132 ... -0.837  1.218 -0.14 ]
#  ...
#  [-0.534  0.359  0.144 ... -0.812  1.235 -0.165]
#  [-0.534  0.356  0.143 ... -0.819  1.228 -0.159]
#  [-0.538  0.357  0.133 ... -0.825  1.224 -0.152]]
#
# TimeInhomogenousRandomizedSignature(max_batch=1000, n_features=100,
#                                     seed=Array([  0, 999], dtype=uint32))
# (150, 100) feat_train
# [[-0.483  0.363  0.132 ... -0.838  1.207 -0.147]
#  [-0.565  0.311  0.137 ... -0.839  1.251 -0.159]
#  [-0.485  0.371  0.132 ... -0.835  1.256 -0.136]
#  ...
#  [-0.655  0.357  0.126 ... -0.809  1.198 -0.226]
#  [-0.535  0.382  0.088 ... -0.781  1.206 -0.165]
#  [-0.537  0.382  0.133 ... -0.852  1.236 -0.114]]
#
# SampledControlledResNet(max_batch=1000, n_features=100,
#                         seed=Array([  0, 999], dtype=uint32),
#                         transform_label_to_onehot=True)
# (150, 100) feat_train
# [[-0.815  0.183  0.991 ... -0.624  0.912  0.815]
#  [ 0.013 -0.723  0.769 ...  0.846  0.761  0.171]
#  [ 0.204  0.943  0.91  ...  0.964  0.251  0.234]
#  ...
#  [-0.169 -0.827  0.954 ... -0.762  0.256  0.399]
#  [-0.289 -0.711  0.448 ...  0.519  0.919  0.603]
#  [-0.333 -0.575  0.96  ...  0.846  0.699 -0.766]]
#
# MultiRocketWrapper(max_batch=10000000, n_features=50000)
# (150, 49728) feat_train
# [[ 0.545  0.818  0.195 ... 44.049  0.5    1.   ]
#  [ 0.636  0.818  0.208 ... 42.081  1.5   -1.   ]
#  [ 0.545  0.818  0.156 ... 42.854  1.667  0.   ]
#  ...
#  [ 0.247  0.753  0.169 ... 32.676  1.5    1.5  ]
#  [ 0.312  0.779  0.208 ... 37.632  1.5    0.   ]
#  [ 0.429  0.87   0.104 ... 41.65   1.5    0.5  ]]
#
# Handwriting Elapsed time 10.485856533050537
# RacketSports
# (151, 30, 6) (152, 30, 6)
# RandomGuesser(max_batch=1000, n_features=100,
#               seed=Array([  0, 999], dtype=uint32))
# (151, 100) feat_train
# [[-1.601 -0.302 -0.68  ... -0.682 -0.944 -0.816]
#  [-0.733 -0.284  0.411 ...  0.119  0.091 -0.192]
#  [ 1.082 -0.813  1.5   ... -0.143 -0.222  0.812]
#  ...
#  [ 0.586 -0.128 -1.529 ...  0.003  0.413 -0.413]
#  [ 1.321  1.38   0.511 ...  0.396  0.49  -0.329]
#  [ 0.364 -1.557 -0.154 ... -0.451  0.754 -1.516]]
#
# TabularTimeseriesFeatures(max_batch=1000)
# (151, 186) feat_train
# [[ 0.     0.     0.    ...  0.194 -0.425 -0.144]
#  [ 0.     0.     0.    ... -1.564 -3.531 -3.25 ]
#  [ 0.     0.     0.    ...  0.486  0.567 -0.216]
#  ...
#  [ 0.     0.     0.    ...  1.166  0.915  0.441]
#  [ 0.     0.     0.    ...  1.378  1.994  2.45 ]
#  [ 0.     0.     0.    ... -0.755  0.232  0.115]]
#
# SigTransform(max_batch=1000, trunc_level=2)
# (151, 42) feat_train
# [[-3.256e-01  1.435e-01 -6.893e-01 ...  4.619e+00 -4.586e+00  1.035e-02]
#  [ 1.422e+00  1.478e-01  4.921e-01 ...  2.426e+00  1.001e+01  5.282e+00]
#  [ 1.226e+00 -9.219e-01 -6.964e-01 ... -1.062e+01  1.756e+01  2.325e-02]
#  ...
#  [ 7.139e-01  1.512e-02 -1.649e+00 ... -1.669e+00 -2.484e+00  9.702e-02]
#  [ 9.811e-01 -5.913e-01  3.010e-01 ... -5.977e-01 -6.430e+00  3.001e+00]
#  [ 1.424e-01  1.279e-01 -2.602e-01 ... -2.411e+00  1.058e+00  6.612e-03]]
#
# RandomizedSignature(max_batch=1000, n_features=100,
#                     seed=Array([  0, 999], dtype=uint32))
# (151, 100) feat_train
# [[-0.539  0.358  0.14  ... -0.823  1.224 -0.149]
#  [-0.541  0.367  0.169 ... -0.834  1.206 -0.148]
#  [-0.548  0.365  0.14  ... -0.826  1.22  -0.16 ]
#  ...
#  [-0.547  0.367  0.129 ... -0.83   1.225 -0.153]
#  [-0.538  0.352  0.12  ... -0.824  1.234 -0.169]
#  [-0.534  0.365  0.132 ... -0.822  1.232 -0.158]]
#
# TimeInhomogenousRandomizedSignature(max_batch=1000, n_features=100,
#                                     seed=Array([  0, 999], dtype=uint32))
# (151, 100) feat_train
# [[-0.483  0.356  0.264 ... -0.774  1.202 -0.069]
#  [-0.552  0.248  0.19  ... -0.891  1.171 -0.237]
#  [-0.642  0.406  0.127 ... -0.769  1.27  -0.063]
#  ...
#  [-0.51   0.385  0.172 ... -0.868  1.236 -0.196]
#  [-0.54   0.263  0.144 ... -0.771  1.19  -0.051]
#  [-0.557  0.353  0.145 ... -0.775  1.2   -0.19 ]]
#
# SampledControlledResNet(max_batch=1000, n_features=100,
#                         seed=Array([  0, 999], dtype=uint32),
#                         transform_label_to_onehot=True)
# (151, 100) feat_train
# [[ 0.386  0.11   0.466 ... -0.971  0.889  0.54 ]
#  [-0.52  -0.476 -0.069 ...  0.55   0.911  0.962]
#  [ 0.482 -0.711 -1.077 ...  0.405  0.937 -0.919]
#  ...
#  [ 0.916  0.94   0.517 ...  1.036 -0.314  0.915]
#  [ 1.015 -0.893  0.998 ...  0.735 -0.912  0.296]
#  [-0.143 -0.903  0.225 ...  1.005 -0.402 -0.931]]
#
# MultiRocketWrapper(max_batch=10000000, n_features=50000)
# (151, 49728) feat_train
# [[0.226 0.903 0.065 ... 1.667 2.5   4.   ]
#  [0.29  0.645 0.161 ... 2.    2.5   2.5  ]
#  [0.355 0.806 0.161 ... 2.25  2.25  2.667]
#  ...
#  [0.323 0.613 0.323 ... 1.5   2.5   1.5  ]
#  [0.194 0.677 0.129 ... 2.    2.5   2.   ]
#  [0.355 0.742 0.258 ... 2.25  2.5   3.   ]]
#
# RacketSports Elapsed time 6.236881971359253
# HandMovementDirection
# (160, 100, 10) (74, 100, 10)
# RandomGuesser(max_batch=1000, n_features=100,
#               seed=Array([  0, 999], dtype=uint32))
# (160, 100) feat_train
# [[-1.925  1.29   2.294 ... -0.453 -0.557 -0.912]
#  [ 0.409 -1.034 -0.297 ... -1.246 -0.382 -0.666]
#  [ 0.082 -0.109  0.016 ...  0.616  0.429  0.083]
#  ...
#  [-0.46   0.144 -1.48  ... -1.517  0.035  1.114]
#  [-0.532  0.379 -0.897 ...  0.809 -0.881 -0.764]
#  [ 0.437 -1.637 -0.885 ...  0.499  0.199 -0.499]]
#
# TabularTimeseriesFeatures(max_batch=1000)
# (160, 1010) feat_train
# [[ 0.     0.     0.    ...  0.396 -0.298  0.674]
#  [ 0.     0.     0.    ...  1.764  1.598  1.531]
#  [ 0.     0.     0.    ...  1.347  1.398  0.971]
#  ...
#  [ 0.     0.     0.    ...  0.918  1.083  0.51 ]
#  [ 0.     0.     0.    ...  0.495 -0.607  0.014]
#  [ 0.     0.     0.    ...  1.422  1.815  2.332]]
#
# SigTransform(max_batch=1000, trunc_level=2)
# (160, 110) feat_train
# [[ 3.585e-02  4.139e-01  7.238e-01 ...  2.412e+00  3.976e+00  2.273e-01]
#  [ 4.220e-01  3.466e-01  4.238e-01 ...  1.779e+00 -2.495e+00  1.172e+00]
#  [ 1.852e+00  2.031e+00  1.335e+00 ...  1.586e+00  2.461e+00  4.715e-01]
#  ...
#  [ 6.729e-01  1.052e+00  9.480e-01 ... -1.894e+00 -1.231e+00  1.303e-01]
#  [-6.976e-01 -9.491e-01 -9.057e-01 ... -3.014e+00 -9.953e-01  1.024e-04]
#  [ 9.436e-01 -6.279e-01 -2.341e-01 ...  6.404e+00  2.898e+00  2.718e+00]]
#
# RandomizedSignature(max_batch=1000, n_features=100,
#                     seed=Array([  0, 999], dtype=uint32))
# (160, 100) feat_train
# [[-0.532  0.358  0.139 ... -0.826  1.226 -0.154]
#  [-0.534  0.357  0.141 ... -0.828  1.228 -0.155]
#  [-0.536  0.361  0.141 ... -0.829  1.227 -0.156]
#  ...
#  [-0.534  0.358  0.142 ... -0.828  1.225 -0.155]
#  [-0.535  0.357  0.135 ... -0.821  1.228 -0.154]
#  [-0.534  0.355  0.142 ... -0.828  1.229 -0.155]]
#
# TimeInhomogenousRandomizedSignature(max_batch=1000, n_features=100,
#                                     seed=Array([  0, 999], dtype=uint32))
# (160, 100) feat_train
# [[-0.536  0.357  0.132 ... -0.804  1.192 -0.153]
#  [-0.535  0.326  0.144 ... -0.82   1.216 -0.145]
#  [-0.516  0.331  0.12  ... -0.863  1.213 -0.143]
#  ...
#  [-0.556  0.407  0.118 ... -0.831  1.194 -0.174]
#  [-0.526  0.383  0.104 ... -0.801  1.222 -0.154]
#  [-0.542  0.358  0.109 ... -0.802  1.257 -0.167]]
#
# SampledControlledResNet(max_batch=1000, n_features=100,
#                         seed=Array([  0, 999], dtype=uint32),
#                         transform_label_to_onehot=True)
# (160, 100) feat_train
# [[-0.971 -0.946 -0.326 ...  0.974  0.65   0.559]
#  [ 0.817  0.762  0.925 ... -0.955 -0.687  0.927]
#  [ 0.882  0.006  0.914 ...  0.235  0.781  0.928]
#  ...
#  [-0.977  0.934 -0.047 ...  0.985  0.979  0.812]
#  [-0.013 -0.804  0.767 ...  0.966  0.862  0.956]
#  [ 0.324  1.014  0.7   ...  0.857 -0.81   0.356]]
#
# MultiRocketWrapper(max_batch=10000000, n_features=50000)
# (160, 49728) feat_train
# [[ 0.406  0.772  0.109 ...  2.    50.235 48.372]
#  [ 0.386  0.683  0.228 ...  1.    51.678 44.795]
#  [ 0.386  0.743  0.188 ...  1.    49.778 47.708]
#  ...
#  [ 0.406  0.653  0.188 ...  2.    49.817 51.729]
#  [ 0.386  0.772  0.059 ...  2.    51.721 50.548]
#  [ 0.446  0.683  0.198 ...  2.    49.304 49.708]]
#
# HandMovementDirection Elapsed time 7.626093626022339
# Libras
# (180, 45, 2) (180, 45, 2)
# RandomGuesser(max_batch=1000, n_features=100,
#               seed=Array([  0, 999], dtype=uint32))
# (180, 100) feat_train
# [[ 0.336 -0.729  1.203 ...  0.811 -0.645  0.223]
#  [ 1.684  1.156 -0.261 ... -1.061 -1.205 -2.042]
#  [-0.011 -1.784  0.184 ...  1.049 -1.99   1.515]
#  ...
#  [-0.022 -0.703 -0.889 ... -0.011  0.328  0.417]
#  [ 1.931 -1.354  0.154 ... -0.483 -0.9   -0.718]
#  [ 0.712  1.109  0.736 ...  0.654  0.659  0.163]]
#
# TabularTimeseriesFeatures(max_batch=1000)
# (180, 92) feat_train
# [[ 0.     0.     0.536 ...  1.267 -1.373  1.236]
#  [ 0.     0.     0.744 ... -1.057  1.273 -0.964]
#  [ 0.     0.     0.498 ... -0.097  0.189 -0.62 ]
#  ...
#  [ 0.     0.     0.346 ...  0.194  0.139  0.179]
#  [ 0.     0.     0.441 ...  0.358  0.231  0.327]
#  [ 0.     0.     0.346 ...  0.194  0.139  0.179]]
#
# SigTransform(max_batch=1000, trunc_level=2)
# (180, 6) feat_train
# [[-1.373  1.236  0.943 -2.751  1.053  0.764]
#  [ 1.273 -0.964  0.81  -2.307  1.08   0.464]
#  [ 0.189 -0.62   0.018 -1.192  1.075  0.192]
#  ...
#  [ 0.139  0.179  0.01  -0.366  0.391  0.016]
#  [ 0.231  0.327  0.027 -0.281  0.356  0.053]
#  [ 0.139  0.179  0.01  -0.366  0.391  0.016]]
#
# RandomizedSignature(max_batch=1000, n_features=100,
#                     seed=Array([  0, 999], dtype=uint32))
# (180, 100) feat_train
# [[-0.536  0.331  0.112 ... -0.804  1.233 -0.17 ]
#  [-0.534  0.381  0.158 ... -0.839  1.224 -0.139]
#  [-0.536  0.367  0.144 ... -0.83   1.222 -0.151]
#  ...
#  [-0.534  0.358  0.137 ... -0.822  1.229 -0.153]
#  [-0.534  0.357  0.136 ... -0.822  1.231 -0.152]
#  [-0.534  0.358  0.137 ... -0.822  1.229 -0.153]]
#
# TimeInhomogenousRandomizedSignature(max_batch=1000, n_features=100,
#                                     seed=Array([  0, 999], dtype=uint32))
# (180, 100) feat_train
# [[-0.531  0.35   0.129 ... -0.839  1.273 -0.17 ]
#  [-0.562  0.37   0.098 ... -0.87   1.256 -0.162]
#  [-0.51   0.36   0.158 ... -0.854  1.246 -0.094]
#  ...
#  [-0.531  0.353  0.149 ... -0.818  1.232 -0.152]
#  [-0.528  0.352  0.15  ... -0.817  1.232 -0.15 ]
#  [-0.531  0.353  0.149 ... -0.818  1.232 -0.152]]
#
# SampledControlledResNet(max_batch=1000, n_features=100,
#                         seed=Array([  0, 999], dtype=uint32),
#                         transform_label_to_onehot=True)
# (180, 100) feat_train
# [[-0.809  0.195  0.997 ...  0.484  0.359 -0.365]
#  [-0.933 -0.965  0.962 ... -0.836  0.898  0.773]
#  [-0.864 -0.983  1.016 ...  0.71   0.951  0.453]
#  ...
#  [ 0.783 -0.599  0.869 ...  0.301 -0.798 -0.109]
#  [ 0.945 -0.41   0.838 ...  0.295 -0.914 -0.108]
#  [ 0.783 -0.599  0.869 ...  0.301 -0.798 -0.109]]
#
# MultiRocketWrapper(max_batch=10000000, n_features=50000)
# (180, 49728) feat_train
# [[ 0.391  0.63   0.152 ...  0.5    2.     0.   ]
#  [ 0.391  0.674  0.109 ...  2.     2.     2.   ]
#  [ 0.326  0.587  0.304 ...  1.667  1.667  1.667]
#  ...
#  [ 0.043  0.891  0.    ... -1.     2.    -1.   ]
#  [ 0.326  0.848  0.    ... -1.     2.25  -1.   ]
#  [ 0.043  0.891  0.    ... -1.     2.    -1.   ]]
#
# Libras Elapsed time 5.628377914428711
# NATOPS
# (180, 51, 24) (180, 51, 24)
# RandomGuesser(max_batch=1000, n_features=100,
#               seed=Array([  0, 999], dtype=uint32))
# (180, 100) feat_train
# [[-0.939  1.389 -0.031 ... -0.055  1.217 -0.225]
#  [ 0.256  0.545 -0.055 ...  1.32  -0.159  0.629]
#  [ 0.338  1.212 -1.072 ...  0.053 -0.364  0.528]
#  ...
#  [-0.722 -3.266  1.372 ... -0.613 -0.383 -1.161]
#  [-1.085 -0.622 -1.339 ...  0.051 -1.299 -1.71 ]
#  [ 0.034 -0.64  -0.41  ... -0.619  0.217 -1.312]]
#
# TabularTimeseriesFeatures(max_batch=1000)
# (180, 1248) feat_train
# [[ 0.     0.     0.    ... -0.091 -0.074 -0.701]
#  [ 0.     0.     0.    ... -0.551  1.104  0.127]
#  [ 0.     0.     0.    ... -0.7    0.439 -0.216]
#  ...
#  [ 0.     0.     0.    ...  0.392  0.869 -0.399]
#  [ 0.     0.     0.    ... -0.605 -1.9    0.231]
#  [ 0.     0.     0.    ... -0.164  0.671 -0.387]]
#
# SigTransform(max_batch=1000, trunc_level=2)
# (180, 600) feat_train
# [[ 0.722  0.591 -0.214 ...  1.687 -4.89   0.246]
#  [ 0.487  1.485 -0.101 ...  0.524  0.292  0.008]
#  [-0.007  0.404  0.189 ...  0.417 -0.745  0.023]
#  ...
#  [ 0.27   0.685  0.664 ... -1.271 -0.213  0.08 ]
#  [ 0.614 -1.057 -0.908 ... -0.43  -2.394  0.027]
#  [ 0.377  0.921 -0.316 ...  5.164  2.416  0.075]]
#
# RandomizedSignature(max_batch=1000, n_features=100,
#                     seed=Array([  0, 999], dtype=uint32))
# (180, 100) feat_train
# [[-0.534  0.356  0.133 ... -0.821  1.228 -0.154]
#  [-0.536  0.356  0.134 ... -0.824  1.227 -0.153]
#  [-0.535  0.357  0.136 ... -0.823  1.226 -0.153]
#  ...
#  [-0.535  0.358  0.132 ... -0.824  1.229 -0.153]
#  [-0.534  0.357  0.144 ... -0.816  1.226 -0.159]
#  [-0.537  0.355  0.137 ... -0.823  1.228 -0.151]]
#
# TimeInhomogenousRandomizedSignature(max_batch=1000, n_features=100,
#                                     seed=Array([  0, 999], dtype=uint32))
# (180, 100) feat_train
# [[-0.532  0.347  0.143 ... -0.817  1.23  -0.157]
#  [-0.533  0.358  0.138 ... -0.819  1.222 -0.156]
#  [-0.534  0.355  0.139 ... -0.824  1.226 -0.153]
#  ...
#  [-0.531  0.356  0.138 ... -0.818  1.224 -0.151]
#  [-0.537  0.37   0.135 ... -0.826  1.234 -0.157]
#  [-0.543  0.357  0.136 ... -0.817  1.229 -0.144]]
#
# SampledControlledResNet(max_batch=1000, n_features=100,
#                         seed=Array([  0, 999], dtype=uint32),
#                         transform_label_to_onehot=True)
# (180, 100) feat_train
# [[-0.085 -0.554  0.743 ... -0.973  0.971 -0.959]
#  [-0.699  0.834  0.963 ...  0.301  0.4    0.729]
#  [-0.315 -0.758  0.988 ...  0.94  -0.742 -0.032]
#  ...
#  [-0.891  0.74   0.757 ...  0.822  0.789 -0.421]
#  [-0.73  -0.989  1.008 ... -1.03   0.73  -0.942]
#  [ 0.638 -0.967  0.687 ... -1.05   0.993 -0.775]]
#
# MultiRocketWrapper(max_batch=10000000, n_features=50000)
# (180, 49728) feat_train
# [[ 0.558  0.615  0.423 ...  1.    27.146 27.647]
#  [ 0.365  0.673  0.25  ...  1.    25.5   22.552]
#  [ 0.346  0.654  0.288 ...  1.    25.5   23.074]
#  ...
#  [ 0.346  0.615  0.288 ...  1.    26.229 21.148]
#  [ 0.5    0.596  0.442 ...  2.    26.8   28.333]
#  [ 0.327  0.654  0.231 ...  0.    26.    24.944]]
#
# NATOPS Elapsed time 6.615517854690552
# SelfRegulationSCP2
# (200, 96, 7) (180, 96, 7)
# RandomGuesser(max_batch=1000, n_features=100,
#               seed=Array([  0, 999], dtype=uint32))
# (200, 100) feat_train
# [[-0.435  1.428 -1.146 ... -1.134  0.875 -0.091]
#  [-0.364  0.15   0.088 ... -0.045 -0.164 -0.298]
#  [-0.347 -0.227 -1.11  ... -1.417  0.048 -1.094]
#  ...
#  [-0.522  0.44   0.181 ... -0.074 -0.477 -0.681]
#  [-0.85   0.619 -1.546 ...  0.182  0.663  0.619]
#  [-0.789 -0.387  0.491 ...  0.648 -0.474  1.172]]
#
# TabularTimeseriesFeatures(max_batch=1000)
# (200, 679) feat_train
# [[ 0.     0.     0.    ... -2.147 -2.006 -1.973]
#  [ 0.     0.     0.    ... -0.556 -0.227 -0.376]
#  [ 0.     0.     0.    ...  1.498  1.167  1.141]
#  ...
#  [ 0.     0.     0.    ...  0.098  0.17   0.284]
#  [ 0.     0.     0.    ... -1.203 -1.262 -1.389]
#  [ 0.     0.     0.    ... -2.005 -2.122 -1.893]]
#
# SigTransform(max_batch=1000, trunc_level=2)
# (200, 56) feat_train
# [[-4.48  -2.921 -1.787 ... 11.868  8.316  1.947]
#  [ 0.457  0.02  -0.325 ...  6.545  5.345  0.071]
#  [ 0.653  1.612  1.652 ...  4.706  3.72   0.651]
#  ...
#  [-0.211 -0.705 -0.584 ...  4.54   4.025  0.04 ]
#  [-0.051 -1.148 -1.092 ...  6.132  5.146  0.965]
#  [-0.369 -1.625 -2.195 ...  8.756  7.873  1.792]]
#
# RandomizedSignature(max_batch=1000, n_features=100,
#                     seed=Array([  0, 999], dtype=uint32))
# (200, 100) feat_train
# [[-0.536  0.358  0.143 ... -0.817  1.224 -0.167]
#  [-0.537  0.36   0.137 ... -0.822  1.225 -0.154]
#  [-0.532  0.354  0.135 ... -0.827  1.23  -0.148]
#  ...
#  [-0.534  0.359  0.137 ... -0.824  1.226 -0.156]
#  [-0.538  0.361  0.139 ... -0.819  1.223 -0.158]
#  [-0.541  0.364  0.139 ... -0.817  1.221 -0.162]]
#
# TimeInhomogenousRandomizedSignature(max_batch=1000, n_features=100,
#                                     seed=Array([  0, 999], dtype=uint32))
# (200, 100) feat_train
# [[-0.536  0.336  0.13  ... -0.813  1.241 -0.169]
#  [-0.526  0.363  0.138 ... -0.827  1.2   -0.148]
#  [-0.548  0.371  0.145 ... -0.825  1.258 -0.174]
#  ...
#  [-0.551  0.352  0.135 ... -0.828  1.239 -0.163]
#  [-0.539  0.376  0.147 ... -0.84   1.204 -0.15 ]
#  [-0.535  0.378  0.148 ... -0.827  1.237 -0.169]]
#
# SampledControlledResNet(max_batch=1000, n_features=100,
#                         seed=Array([  0, 999], dtype=uint32),
#                         transform_label_to_onehot=True)
# (200, 100) feat_train
# [[ 1.013  1.012 -0.965 ... -0.964  0.218  1.002]
#  [-0.962 -0.591  0.974 ...  0.475  0.428 -0.376]
#  [-0.971 -1.005  0.939 ...  0.794  0.865 -0.851]
#  ...
#  [-0.978 -0.617  0.981 ... -0.275  0.185 -0.618]
#  [ 0.948  0.555  0.996 ... -0.507  0.346  0.983]
#  [ 0.83   0.643  0.761 ...  0.435 -0.075  0.196]]
#
# MultiRocketWrapper(max_batch=10000000, n_features=50000)
# (200, 49728) feat_train
# [[ 0.402  0.835  0.175 ... 46.667  3.5    4.5  ]
#  [ 0.33   0.784  0.113 ... 46.614  3.143  5.   ]
#  [ 0.289  0.825  0.113 ... 48.66   3.5    2.75 ]
#  ...
#  [ 0.278  0.753  0.103 ... 48.286  3.5    4.333]
#  [ 0.32   0.742  0.124 ... 46.34   3.286  3.333]
#  [ 0.34   0.753  0.186 ... 46.24   3.429  2.667]]
#
# SelfRegulationSCP2 Elapsed time 8.936890125274658
# Heartbeat
# (204, 81, 61) (205, 81, 61)
# RandomGuesser(max_batch=1000, n_features=100,
#               seed=Array([  0, 999], dtype=uint32))
# (204, 100) feat_train
# [[-0.573 -1.319 -0.181 ... -1.661 -0.267  1.192]
#  [-0.559  0.055 -0.643 ... -0.105  0.348  0.572]
#  [ 2.152 -0.6    0.252 ... -0.437  0.282  3.262]
#  ...
#  [ 0.466  0.295  0.582 ...  0.118 -0.2   -1.475]
#  [-0.117  0.362  1.221 ...  0.895 -0.685 -0.389]
#  [ 3.916 -0.067  0.638 ... -1.078  1.741 -0.643]]
#
# TabularTimeseriesFeatures(max_batch=1000)
# (204, 5002) feat_train
# [[ 0.     0.     0.    ... -0.359 -0.472 -0.678]
#  [ 0.     0.     0.    ... -0.639 -0.691 -0.635]
#  [ 0.     0.     0.    ...  0.106  0.49  -0.359]
#  ...
#  [ 0.     0.     0.    ... -0.194 -0.001  0.283]
#  [ 0.     0.     0.    ... -0.749 -0.863 -0.715]
#  [ 0.     0.     0.    ... -0.615 -0.765 -0.764]]
#
# SigTransform(max_batch=1000, trunc_level=2)
# (204, 3782) feat_train
# [[-5.897e-01 -5.345e-01 -5.691e-01 ...  9.651e-02  8.803e-02  2.202e-01]
#  [ 7.478e-01  7.019e-01  6.690e-01 ... -1.117e-03  2.104e-01  1.934e-01]
#  [-1.691e-01 -1.954e-01 -2.147e-01 ... -6.440e+00 -3.754e+00  6.281e-02]
#  ...
#  [ 1.483e+00  1.261e+00  1.363e+00 ... -1.086e-01 -2.221e-01  3.615e-02]
#  [-8.047e-02  1.469e-01  3.002e-01 ...  4.467e-01  4.904e-01  2.446e-01]
#  [ 2.198e-01 -8.658e-02 -2.721e-01 ... -4.675e-01 -7.018e-01  2.791e-01]]
#
# RandomizedSignature(max_batch=1000, n_features=100,
#                     seed=Array([  0, 999], dtype=uint32))
# (204, 100) feat_train
# [[-0.535  0.358  0.137 ... -0.824  1.227 -0.154]
#  [-0.535  0.358  0.136 ... -0.823  1.227 -0.155]
#  [-0.535  0.358  0.137 ... -0.823  1.226 -0.154]
#  ...
#  [-0.535  0.357  0.14  ... -0.824  1.227 -0.156]
#  [-0.534  0.359  0.137 ... -0.824  1.227 -0.155]
#  [-0.535  0.358  0.137 ... -0.824  1.227 -0.154]]
#
# TimeInhomogenousRandomizedSignature(max_batch=1000, n_features=100,
#                                     seed=Array([  0, 999], dtype=uint32))
# (204, 100) feat_train
# [[-0.535  0.358  0.137 ... -0.826  1.228 -0.152]
#  [-0.533  0.364  0.143 ... -0.817  1.224 -0.162]
#  [-0.535  0.352  0.136 ... -0.825  1.219 -0.155]
#  ...
#  [-0.537  0.352  0.135 ... -0.829  1.231 -0.145]
#  [-0.536  0.357  0.141 ... -0.825  1.227 -0.152]
#  [-0.533  0.362  0.135 ... -0.82   1.223 -0.155]]
#
# SampledControlledResNet(max_batch=1000, n_features=100,
#                         seed=Array([  0, 999], dtype=uint32),
#                         transform_label_to_onehot=True)
# (204, 100) feat_train
# [[-0.663  0.476  0.985 ...  0.204 -0.355  0.139]
#  [ 0.356 -1.232  0.639 ...  0.729 -0.71  -0.123]
#  [-0.728  0.293  0.845 ...  0.846 -0.52   0.08 ]
#  ...
#  [-0.054  0.379  0.924 ...  0.247  0.401  0.884]
#  [ 0.042 -0.177  0.986 ...  0.13  -0.037  0.535]
#  [-0.312 -0.397  0.938 ... -0.586  0.283 -0.045]]
#
# MultiRocketWrapper(max_batch=10000000, n_features=50000)
# (204, 49728) feat_train
# [[0.195 0.988 0.049 ... 4.5   4.    4.333]
#  [0.341 0.829 0.098 ... 3.5   3.286 3.5  ]
#  [0.439 0.817 0.049 ... 3.8   3.625 4.333]
#  ...
#  [0.366 0.659 0.134 ... 4.4   4.571 4.4  ]
#  [0.268 1.    0.    ... 4.6   4.5   3.   ]
#  [0.317 0.854 0.11  ... 4.    4.    3.667]]
#
# Heartbeat Elapsed time 12.613061904907227
# EthanolConcentration
# (261, 98, 3) (263, 98, 3)
# RandomGuesser(max_batch=1000, n_features=100,
#               seed=Array([  0, 999], dtype=uint32))
# (261, 100) feat_train
# [[-0.804  2.031 -0.078 ...  1.397  0.991 -0.613]
#  [-1.628 -1.291  0.53  ...  0.479  0.889  0.228]
#  [-0.666 -0.615 -0.576 ... -0.091  0.895  1.098]
#  ...
#  [-0.003  0.43   0.687 ...  0.029  0.716  0.164]
#  [ 0.887  0.534 -0.078 ...  1.496 -0.008  1.038]
#  [-1.393  0.867  0.927 ...  1.969  1.172 -1.58 ]]
#
# TabularTimeseriesFeatures(max_batch=1000)
# (261, 297) feat_train
# [[ 0.     0.     0.    ...  0.566  0.502  0.468]
#  [ 0.     0.     0.    ...  0.723  0.799  0.77 ]
#  [ 0.     0.     0.    ...  0.627  0.562  0.509]
#  ...
#  [ 0.     0.     0.    ... -1.637 -1.616 -1.663]
#  [ 0.     0.     0.    ... -1.621 -1.604 -1.651]
#  [ 0.     0.     0.    ...  0.587  0.765  0.745]]
#
# SigTransform(max_batch=1000, trunc_level=2)
# (261, 12) feat_train
# [[ 0.566  0.502  0.468 ... -0.044 -0.096  0.109]
#  [ 0.723  0.799  0.77  ... -0.008 -0.724  0.297]
#  [ 0.627  0.562  0.509 ...  0.349  0.216  0.13 ]
#  ...
#  [-1.637 -1.616 -1.663 ...  1.85   1.536  1.383]
#  [-1.621 -1.604 -1.651 ...  1.596  1.58   1.362]
#  [ 0.587  0.765  0.745 ...  0.207 -0.327  0.278]]
#
# RandomizedSignature(max_batch=1000, n_features=100,
#                     seed=Array([  0, 999], dtype=uint32))
# (261, 100) feat_train
# [[-0.536  0.358  0.138 ... -0.818  1.23  -0.159]
#  [-0.537  0.358  0.138 ... -0.816  1.231 -0.161]
#  [-0.536  0.358  0.138 ... -0.818  1.23  -0.159]
#  ...
#  [-0.531  0.358  0.135 ... -0.838  1.216 -0.139]
#  [-0.531  0.358  0.135 ... -0.838  1.216 -0.139]
#  [-0.537  0.358  0.137 ... -0.817  1.231 -0.161]]
#
# TimeInhomogenousRandomizedSignature(max_batch=1000, n_features=100,
#                                     seed=Array([  0, 999], dtype=uint32))
# (261, 100) feat_train
# [[-0.534  0.358  0.141 ... -0.827  1.227 -0.156]
#  [-0.534  0.364  0.145 ... -0.831  1.221 -0.158]
#  [-0.536  0.352  0.14  ... -0.829  1.231 -0.155]
#  ...
#  [-0.527  0.354  0.135 ... -0.816  1.222 -0.158]
#  [-0.532  0.359  0.14  ... -0.822  1.216 -0.161]
#  [-0.536  0.368  0.137 ... -0.824  1.232 -0.152]]
#
# SampledControlledResNet(max_batch=1000, n_features=100,
#                         seed=Array([  0, 999], dtype=uint32),
#                         transform_label_to_onehot=True)
# (261, 100) feat_train
# [[ 0.652 -0.856  0.892 ...  0.871 -0.819 -0.477]
#  [-0.954 -0.99   0.982 ...  0.718  0.236  0.531]
#  [ 0.72  -0.907  0.955 ...  0.805 -0.902 -0.299]
#  ...
#  [-0.95   0.989  0.979 ... -0.982  0.95   0.934]
#  [-0.916  0.964  0.964 ... -0.989  0.88   0.84 ]
#  [-0.99  -0.72   0.942 ...  0.966  0.124  0.638]]
#
# MultiRocketWrapper(max_batch=10000000, n_features=50000)
# (261, 49728) feat_train
# [[ 3.737e-01  7.879e-01  1.414e-01 ...  5.000e-01  5.182e+01  4.493e+01]
#  [ 3.535e-01  7.677e-01  1.515e-01 ... -1.000e+00  5.150e+01  4.284e+01]
#  [ 4.040e-01  7.879e-01  1.313e-01 ...  5.000e-01  5.049e+01  4.623e+01]
#  ...
#  [ 3.535e-01  7.677e-01  1.717e-01 ...  1.000e+00  5.081e+01  4.889e+01]
#  [ 4.343e-01  7.475e-01  1.818e-01 ... -1.000e+00  5.188e+01  4.626e+01]
#  [ 3.434e-01  8.485e-01  5.051e-02 ...  5.000e-01  5.035e+01  4.268e+01]]
#
# EthanolConcentration Elapsed time 9.158784866333008
# SelfRegulationSCP1
# (268, 100, 6) (293, 100, 6)
# RandomGuesser(max_batch=1000, n_features=100,
#               seed=Array([  0, 999], dtype=uint32))
# (268, 100) feat_train
# [[ 0.194  0.123  0.438 ...  2.24   1.252  1.454]
#  [ 0.182  0.194  0.471 ...  1.094  0.08   0.714]
#  [ 0.856 -0.766 -1.343 ... -0.986  1.275  2.168]
#  ...
#  [ 0.761 -0.417 -1.093 ...  0.887  1.686  0.015]
#  [ 2.284 -0.775  0.025 ... -1.712 -0.15  -1.352]
#  [-1.053 -1.512  2.026 ...  1.375 -1.051 -0.335]]
#
# TabularTimeseriesFeatures(max_batch=1000)
# (268, 606) feat_train
# [[ 0.     0.     0.    ...  2.241  2.157  2.041]
#  [ 0.     0.     0.    ... -0.066  0.011  0.621]
#  [ 0.     0.     0.    ... -0.807 -0.905 -0.671]
#  ...
#  [ 0.     0.     0.    ...  0.602  0.48   0.424]
#  [ 0.     0.     0.    ... -0.829 -1.145 -1.726]
#  [ 0.     0.     0.    ... -0.036 -0.405  0.293]]
#
# SigTransform(max_batch=1000, trunc_level=2)
# (268, 42) feat_train
# [[ 0.086  1.334  1.579 ...  6.918  5.81   2.083]
#  [ 0.96  -0.281 -0.078 ...  1.693  1.888  0.193]
#  [ 0.188 -0.466 -0.287 ...  3.732  3.26   0.225]
#  ...
#  [ 1.352  0.699  0.551 ...  6.671  4.675  0.09 ]
#  [-1.04  -1.893 -1.165 ...  2.808  2.892  1.489]
#  [ 1.005 -0.056  0.259 ...  2.511  2.738  0.043]]
#
# RandomizedSignature(max_batch=1000, n_features=100,
#                     seed=Array([  0, 999], dtype=uint32))
# (268, 100) feat_train
# [[-0.533  0.355  0.134 ... -0.827  1.231 -0.159]
#  [-0.536  0.359  0.136 ... -0.824  1.227 -0.156]
#  [-0.536  0.359  0.138 ... -0.822  1.225 -0.153]
#  ...
#  [-0.536  0.36   0.137 ... -0.827  1.228 -0.158]
#  [-0.536  0.357  0.139 ... -0.819  1.222 -0.148]
#  [-0.536  0.358  0.138 ... -0.824  1.227 -0.156]]
#
# TimeInhomogenousRandomizedSignature(max_batch=1000, n_features=100,
#                                     seed=Array([  0, 999], dtype=uint32))
# (268, 100) feat_train
# [[-0.546  0.363  0.133 ... -0.82   1.223 -0.16 ]
#  [-0.538  0.365  0.14  ... -0.812  1.222 -0.151]
#  [-0.541  0.358  0.13  ... -0.806  1.22  -0.154]
#  ...
#  [-0.539  0.365  0.148 ... -0.823  1.216 -0.16 ]
#  [-0.538  0.352  0.15  ... -0.813  1.224 -0.156]
#  [-0.542  0.365  0.126 ... -0.822  1.218 -0.152]]
#
# SampledControlledResNet(max_batch=1000, n_features=100,
#                         seed=Array([  0, 999], dtype=uint32),
#                         transform_label_to_onehot=True)
# (268, 100) feat_train
# [[-0.216  0.482  0.987 ... -0.521 -0.224  0.657]
#  [ 0.203  0.425  0.969 ... -0.491 -0.136  0.94 ]
#  [ 0.201  0.264  0.986 ...  0.432 -0.414  0.964]
#  ...
#  [ 0.698  0.734  0.968 ... -0.101 -0.899  0.993]
#  [-1.012 -0.743  0.976 ...  0.857  0.999 -0.996]
#  [ 0.634  0.218  0.989 ... -0.008 -0.874  0.951]]
#
# MultiRocketWrapper(max_batch=10000000, n_features=50000)
# (268, 49728) feat_train
# [[2.475e-01 8.020e-01 7.921e-02 ... 2.500e+00 4.884e+01 4.447e+01]
#  [2.673e-01 8.416e-01 9.901e-03 ... 1.000e+00 5.018e+01 4.932e+01]
#  [3.663e-01 7.525e-01 7.921e-02 ... 1.500e+00 4.983e+01 4.765e+01]
#  ...
#  [2.970e-01 6.634e-01 2.079e-01 ... 1.000e+00 5.118e+01 4.433e+01]
#  [2.871e-01 8.218e-01 1.386e-01 ... 1.333e+00 5.129e+01 5.480e+01]
#  [2.673e-01 7.921e-01 8.911e-02 ... 1.500e+00 5.068e+01 4.590e+01]]
#
# SelfRegulationSCP1 Elapsed time 9.801886081695557
# ArticularyWordRecognition
# (275, 72, 9) (300, 72, 9)
# RandomGuesser(max_batch=1000, n_features=100,
#               seed=Array([  0, 999], dtype=uint32))
# (275, 100) feat_train
# [[-1.189  0.521  0.3   ... -0.716  0.529  0.638]
#  [-1.692  1.284 -1.556 ...  0.115 -1.708  0.639]
#  [-0.123  1.103  1.779 ... -1.95  -0.507  0.256]
#  ...
#  [-1.096  0.784 -0.806 ...  0.091 -0.227 -1.038]
#  [ 0.045  1.656  0.36  ... -0.603  0.54   0.321]
#  [ 0.661 -0.227 -1.41  ...  0.232  0.548 -0.492]]
#
# TabularTimeseriesFeatures(max_batch=1000)
# (275, 657) feat_train
# [[ 0.     0.     0.    ... -0.373 -2.177 -0.749]
#  [ 0.     0.     0.    ...  1.462 -2.636 -1.094]
#  [ 0.     0.     0.    ... -0.197 -1.047 -1.136]
#  ...
#  [ 0.     0.     0.    ... -1.049  0.843 -0.135]
#  [ 0.     0.     0.    ... -0.388  0.186 -0.632]
#  [ 0.     0.     0.    ... -0.48  -0.066 -0.85 ]]
#
# SigTransform(max_batch=1000, trunc_level=2)
# (275, 90) feat_train
# [[-0.45   1.629  0.852 ...  0.571  2.211  0.28 ]
#  [ 0.577  2.271  2.976 ... -0.584  5.007  0.598]
#  [-0.696  1.167  0.008 ...  0.016 -1.653  0.646]
#  ...
#  [-1.582  0.111  0.316 ...  1.366 -1.025  0.009]
#  [-0.726  0.355  0.324 ... -0.399 -1.234  0.199]
#  [-0.481 -0.585 -0.576 ... -0.854  1.734  0.361]]
#
# RandomizedSignature(max_batch=1000, n_features=100,
#                     seed=Array([  0, 999], dtype=uint32))
# (275, 100) feat_train
# [[-0.533  0.363  0.137 ... -0.822  1.226 -0.153]
#  [-0.531  0.363  0.133 ... -0.825  1.225 -0.153]
#  [-0.532  0.363  0.139 ... -0.823  1.225 -0.154]
#  ...
#  [-0.532  0.357  0.138 ... -0.823  1.225 -0.158]
#  [-0.532  0.359  0.137 ... -0.825  1.225 -0.157]
#  [-0.533  0.361  0.138 ... -0.822  1.227 -0.156]]
#
# TimeInhomogenousRandomizedSignature(max_batch=1000, n_features=100,
#                                     seed=Array([  0, 999], dtype=uint32))
# (275, 100) feat_train
# [[-0.539  0.353  0.133 ... -0.821  1.222 -0.162]
#  [-0.54   0.35   0.127 ... -0.82   1.231 -0.133]
#  [-0.543  0.354  0.134 ... -0.826  1.232 -0.151]
#  ...
#  [-0.536  0.343  0.144 ... -0.829  1.236 -0.155]
#  [-0.523  0.348  0.145 ... -0.818  1.237 -0.141]
#  [-0.532  0.374  0.13  ... -0.813  1.235 -0.149]]
#
# SampledControlledResNet(max_batch=1000, n_features=100,
#                         seed=Array([  0, 999], dtype=uint32),
#                         transform_label_to_onehot=True)
# (275, 100) feat_train
# [[-0.564  0.817  0.991 ...  0.917 -0.279  0.483]
#  [-0.967  0.07   0.944 ...  0.757  0.728  0.048]
#  [ 0.044  0.766  0.993 ...  0.902 -0.808  0.793]
#  ...
#  [-0.752  0.984  0.834 ...  0.905 -0.098  0.321]
#  [-0.911  0.971  0.82  ...  1.     0.662  0.76 ]
#  [-0.586  0.926  0.941 ...  0.965  0.815  0.768]]
#
# MultiRocketWrapper(max_batch=10000000, n_features=50000)
# (275, 49728) feat_train
# [[ 0.384  0.603  0.233 ... 48.333 40.69  45.815]
#  [ 0.507  0.767  0.11  ... 35.476 37.323 33.548]
#  [ 0.329  0.589  0.247 ... 47.385 41.105 46.296]
#  ...
#  [ 0.438  0.932  0.055 ... 36.778 35.757 32.286]
#  [ 0.589  0.699  0.082 ... 31.027 35.619 25.16 ]
#  [ 0.548  0.726  0.096 ... 34.083 35.477 32.217]]
#
# ArticularyWordRecognition Elapsed time 9.278155326843262
# MotorImagery
# (278, 100, 64) (100, 100, 64)
# RandomGuesser(max_batch=1000, n_features=100,
#               seed=Array([  0, 999], dtype=uint32))
# (278, 100) feat_train
# [[-0.094 -0.455 -0.623 ... -1.106  1.793  0.581]
#  [ 1.642 -1.055 -0.586 ... -0.012 -0.076  1.582]
#  [-1.612  2.319  0.303 ... -0.524 -0.594 -0.712]
#  ...
#  [-0.662  1.471  0.076 ... -0.462  0.658  0.085]
#  [-1.25  -0.146 -0.146 ... -1.633 -0.551 -1.643]
#  [ 0.047 -2.076  1.54  ... -1.041  0.844  1.357]]
#
# TabularTimeseriesFeatures(max_batch=1000)
# (278, 6464) feat_train
# [[ 0.     0.     0.    ...  0.033 -1.157 -0.543]
#  [ 0.     0.     0.    ... -0.102 -0.248 -0.895]
#  [ 0.     0.     0.    ... -1.038 -0.962 -0.349]
#  ...
#  [ 0.     0.     0.    ...  1.92   0.424  0.402]
#  [ 0.     0.     0.    ...  0.476  1.336 -0.186]
#  [ 0.     0.     0.    ...  1.027  0.278  0.522]]
#
# SigTransform(max_batch=1000, trunc_level=2)
# (278, 4160) feat_train
# [[-0.697 -1.527 -1.143 ...  1.02   5.901  0.148]
#  [-0.461 -0.034 -0.83  ...  0.762  5.145  0.4  ]
#  [-1.933  0.493  1.227 ...  4.094  7.291  0.061]
#  ...
#  [-1.62   0.89   1.561 ...  4.947  4.419  0.081]
#  [ 0.397  0.364  0.688 ...  1.778  6.638  0.017]
#  [ 2.017 -1.279 -1.201 ...  4.985  5.477  0.136]]
#
# RandomizedSignature(max_batch=1000, n_features=100,
#                     seed=Array([  0, 999], dtype=uint32))
# (278, 100) feat_train
# [[-0.535  0.358  0.136 ... -0.826  1.227 -0.156]
#  [-0.535  0.358  0.136 ... -0.824  1.227 -0.154]
#  [-0.536  0.357  0.138 ... -0.824  1.227 -0.154]
#  ...
#  [-0.534  0.358  0.139 ... -0.823  1.227 -0.153]
#  [-0.535  0.359  0.136 ... -0.823  1.227 -0.154]
#  [-0.536  0.359  0.134 ... -0.822  1.226 -0.154]]
#
# TimeInhomogenousRandomizedSignature(max_batch=1000, n_features=100,
#                                     seed=Array([  0, 999], dtype=uint32))
# (278, 100) feat_train
# [[-0.534  0.361  0.138 ... -0.822  1.228 -0.146]
#  [-0.537  0.359  0.134 ... -0.82   1.222 -0.155]
#  [-0.535  0.359  0.134 ... -0.825  1.229 -0.157]
#  ...
#  [-0.526  0.366  0.129 ... -0.827  1.228 -0.157]
#  [-0.542  0.358  0.136 ... -0.818  1.229 -0.156]
#  [-0.532  0.343  0.139 ... -0.821  1.229 -0.153]]
#
# SampledControlledResNet(max_batch=1000, n_features=100,
#                         seed=Array([  0, 999], dtype=uint32),
#                         transform_label_to_onehot=True)
# (278, 100) feat_train
# [[-0.913  0.12   0.98  ...  1.033  0.928 -0.781]
#  [-1.008 -0.523  0.975 ...  0.962 -0.541 -0.316]
#  [-1.01  -0.106 -0.344 ...  1.006 -1.041  0.834]
#  ...
#  [-0.76  -0.84  -0.358 ... -0.506 -0.915  1.058]
#  [-0.714 -0.098  1.    ...  0.384  0.834  0.307]
#  [-0.432  0.279  0.981 ... -0.541  0.962 -0.723]]
#
# MultiRocketWrapper(max_batch=10000000, n_features=50000)
# (278, 49728) feat_train
# [[ 0.455  0.693  0.257 ...  1.333 51.943 45.583]
#  [ 0.317  0.663  0.198 ...  1.5   51.449 45.154]
#  [ 0.277  0.485  0.178 ...  1.    50.726 40.441]
#  ...
#  [ 0.297  0.545  0.149 ...  2.5   48.414 40.351]
#  [ 0.356  0.683  0.188 ...  2.5   50.074 53.065]
#  [ 0.485  0.693  0.297 ...  1.    52.116 49.061]]
#
# MotorImagery Elapsed time 29.609848499298096
# FingerMovements
# (316, 50, 28) (100, 50, 28)
# RandomGuesser(max_batch=1000, n_features=100,
#               seed=Array([  0, 999], dtype=uint32))
# (316, 100) feat_train
# [[-0.211 -1.694 -0.352 ... -0.053  0.926  0.936]
#  [ 0.745  1.307  1.18  ... -0.995 -1.602  0.031]
#  [-1.455  0.244  0.31  ... -1.239  1.556 -1.498]
#  ...
#  [-0.205 -0.193  0.946 ... -0.212 -1.09   0.222]
#  [-2.347 -2.225  2.718 ...  0.669  0.346 -1.348]
#  [ 1.038  1.448 -0.985 ... -0.1    1.748  2.008]]
#
# TabularTimeseriesFeatures(max_batch=1000)
# (316, 1428) feat_train
# [[ 0.     0.     0.    ...  1.294  1.122 -0.236]
#  [ 0.     0.     0.    ... -1.223 -1.562 -1.364]
#  [ 0.     0.     0.    ...  0.054 -0.01  -0.626]
#  ...
#  [ 0.     0.     0.    ...  0.227 -0.088  0.501]
#  [ 0.     0.     0.    ...  0.615  0.254  0.705]
#  [ 0.     0.     0.    ...  2.319  2.291  2.338]]
#
# SigTransform(max_batch=1000, trunc_level=2)
# (316, 812) feat_train
# [[ 0.445  0.453 -0.747 ...  2.166  0.377  0.028]
#  [ 0.834 -1.166 -1.152 ...  1.104  1.087  0.93 ]
#  [-0.247 -0.42  -1.06  ... -0.017  0.185  0.196]
#  ...
#  [ 0.223 -0.636  0.203 ...  0.859  0.819  0.126]
#  [ 0.17   0.374  1.594 ...  0.222  0.256  0.248]
#  [ 0.729  1.025  1.492 ...  2.541  2.612  2.734]]
#
# RandomizedSignature(max_batch=1000, n_features=100,
#                     seed=Array([  0, 999], dtype=uint32))
# (316, 100) feat_train
# [[-0.533  0.358  0.134 ... -0.823  1.23  -0.153]
#  [-0.536  0.361  0.141 ... -0.827  1.221 -0.158]
#  [-0.535  0.359  0.137 ... -0.824  1.225 -0.153]
#  ...
#  [-0.536  0.357  0.138 ... -0.823  1.227 -0.154]
#  [-0.539  0.355  0.135 ... -0.822  1.233 -0.155]
#  [-0.539  0.353  0.128 ... -0.822  1.24  -0.152]]
#
# TimeInhomogenousRandomizedSignature(max_batch=1000, n_features=100,
#                                     seed=Array([  0, 999], dtype=uint32))
# (316, 100) feat_train
# [[-0.551  0.361  0.15  ... -0.82   1.217 -0.145]
#  [-0.524  0.349  0.154 ... -0.828  1.224 -0.148]
#  [-0.544  0.35   0.156 ... -0.827  1.228 -0.141]
#  ...
#  [-0.531  0.368  0.136 ... -0.829  1.236 -0.152]
#  [-0.537  0.367  0.116 ... -0.829  1.237 -0.171]
#  [-0.542  0.36   0.131 ... -0.822  1.228 -0.164]]
#
# SampledControlledResNet(max_batch=1000, n_features=100,
#                         seed=Array([  0, 999], dtype=uint32),
#                         transform_label_to_onehot=True)
# (316, 100) feat_train
# [[-0.945  0.046  0.962 ...  0.111 -0.884  0.295]
#  [-0.934 -0.21   1.05  ...  0.761  0.978  0.66 ]
#  [-0.518 -0.347  1.052 ...  0.149 -0.247  0.776]
#  ...
#  [-0.758 -0.35   0.993 ...  0.386 -0.065  0.089]
#  [-0.298 -0.898  0.269 ... -0.459  0.187 -0.926]
#  [-0.233 -0.775 -0.847 ... -0.911 -0.899 -0.969]]
#
# MultiRocketWrapper(max_batch=10000000, n_features=50000)
# (316, 49728) feat_train
# [[ 3.922e-01  6.471e-01  2.353e-01 ...  0.000e+00  2.456e+01  2.455e+01]
#  [ 4.902e-01  9.216e-01  1.373e-01 ... -1.000e+00  2.578e+01  2.029e+01]
#  [ 3.922e-01  9.216e-01  1.961e-02 ...  0.000e+00  2.526e+01  2.629e+01]
#  ...
#  [ 3.922e-01  8.627e-01  2.353e-01 ...  5.000e-01  2.595e+01  2.380e+01]
#  [ 4.118e-01  8.431e-01  9.804e-02 ...  1.000e+00  2.565e+01  2.500e+01]
#  [ 3.529e-01  8.824e-01  5.882e-02 ...  1.000e+00  2.893e+01  2.548e+01]]
#
# FingerMovements Elapsed time 7.903228998184204
#                              acc_test                                      \
#                           MultiRocket Random Guesser Randomized Signature
# Cricket                      0.972222       0.041667             0.736111
# UWaveGestureLibrary          0.946875       0.153125             0.378125
# EigenWorms                   0.816794       0.419847             0.419847
# Epilepsy                     0.992754       0.210145             0.768116
# Handwriting                  0.372941       0.031765             0.135294
# RacketSports                 0.842105       0.250000             0.486842
# HandMovementDirection        0.270270       0.283784             0.310811
# Libras                       0.950000       0.072222             0.288889
# NATOPS                       0.866667       0.150000             0.227778
# SelfRegulationSCP2           0.600000       0.438889             0.500000
# Heartbeat                    0.726829       0.721951             0.721951
# EthanolConcentration         0.403042       0.247148             0.323194
# SelfRegulationSCP1           0.822526       0.552901             0.679181
# ArticularyWordRecognition    0.990000       0.050000             0.553333
# MotorImagery                 0.510000       0.450000             0.440000
# FingerMovements              0.500000       0.430000             0.480000
#
#                                                                          \
#                           Sampled Controlled ResNet       Sig   Tabular
# Cricket                                    0.847222  0.930556  0.875000
# UWaveGestureLibrary                        0.825000  0.593750  0.818750
# EigenWorms                                 0.488550  0.580153  0.488550
# Epilepsy                                   0.652174  0.500000  0.507246
# Handwriting                                0.151765  0.165882  0.165882
# RacketSports                               0.690789  0.605263  0.796053
# HandMovementDirection                      0.418919  0.189189  0.594595
# Libras                                     0.750000  0.355556  0.600000
# NATOPS                                     0.766667  0.644444  0.877778
# SelfRegulationSCP2                         0.511111  0.527778  0.516667
# Heartbeat                                  0.756098  0.731707  0.731707
# EthanolConcentration                       0.403042  0.300380  0.574144
# SelfRegulationSCP1                         0.890785  0.682594  0.866894
# ArticularyWordRecognition                  0.956667  0.936667  0.953333
# MotorImagery                               0.480000  0.470000  0.470000
# FingerMovements                            0.490000  0.510000  0.640000
#
#                                                                    acc_train  \
#                           Time Inhomogenous Randomized Signature MultiRocket
# Cricket                                                 0.347222         1.0
# UWaveGestureLibrary                                     0.712500         1.0
# EigenWorms                                              0.419847         1.0
# Epilepsy                                                0.304348         1.0
# Handwriting                                             0.090588         1.0
# RacketSports                                            0.559211         1.0
# HandMovementDirection                                   0.216216         1.0
# Libras                                                  0.583333         1.0
# NATOPS                                                  0.483333         1.0
# SelfRegulationSCP2                                      0.555556         1.0
# Heartbeat                                               0.721951         1.0
# EthanolConcentration                                    0.517110         1.0
# SelfRegulationSCP1                                      0.583618         1.0
# ArticularyWordRecognition                               0.543333         1.0
# MotorImagery                                            0.460000         1.0
# FingerMovements                                         0.510000         1.0
#
#                                                                ...   t_ridge  \
#                           Random Guesser Randomized Signature  ...       Sig
# Cricket                         0.962963             0.731481  ...  0.006672
# UWaveGestureLibrary             0.891667             0.500000  ...  0.004562
# EigenWorms                      0.429688             0.445312  ...  0.006910
# Epilepsy                        0.729927             0.788321  ...  0.004839
# Handwriting                     0.880000             0.260000  ...  0.005603
# RacketSports                    0.701987             0.675497  ...  0.007462
# HandMovementDirection           0.768750             0.443750  ...  0.025418
# Libras                          0.872222             0.261111  ...  0.004972
# NATOPS                          0.783333             0.272222  ...  0.067336
# SelfRegulationSCP2              0.800000             0.495000  ...  0.021629
# Heartbeat                       0.720588             0.720588  ...  0.033649
# EthanolConcentration            0.647510             0.340996  ...  0.004887
# SelfRegulationSCP1              0.742537             0.626866  ...  0.021680
# ArticularyWordRecognition       0.883636             0.585455  ...  0.032020
# MotorImagery                    0.744604             0.582734  ...  0.088991
# FingerMovements                 0.718354             0.642405  ...  0.061232
#
#                                                                             \
#                             Tabular Time Inhomogenous Randomized Signature
# Cricket                    0.030580                               0.032804
# UWaveGestureLibrary        0.032292                               0.056440
# EigenWorms                 0.018428                               0.043537
# Epilepsy                   0.039137                               0.015780
# Handwriting                0.021941                               0.071448
# RacketSports               0.039491                               0.028093
# HandMovementDirection      0.033940                               0.031825
# Libras                     0.024052                               0.014717
# NATOPS                     0.040972                               0.078322
# SelfRegulationSCP2         0.039724                               0.040871
# Heartbeat                  0.041772                               0.225710
# EthanolConcentration       0.024018                               0.025962
# SelfRegulationSCP1         0.049768                               0.055888
# ArticularyWordRecognition  0.051451                               0.066382
# MotorImagery               0.082305                               0.153943
# FingerMovements            0.042741                               0.059125
#
#                           t_trans_feat                                      \
#                            MultiRocket Random Guesser Randomized Signature
# Cricket                       1.280821       0.068515             0.401139
# UWaveGestureLibrary           1.743961       0.020035             0.377276
# EigenWorms                    1.659951       0.020235             0.354935
# Epilepsy                      0.950727       0.022590             0.330499
# Handwriting                   4.181562       0.023113             0.399905
# RacketSports                  0.539171       0.020911             0.333153
# HandMovementDirection         1.614564       0.019469             0.357543
# Libras                        0.757100       0.013312             0.213580
# NATOPS                        1.041514       0.012415             0.235716
# SelfRegulationSCP2            2.076099       0.020489             0.347157
# Heartbeat                     2.528973       0.021622             0.584635
# EthanolConcentration          2.499432       0.022100             0.344011
# SelfRegulationSCP1            3.116620       0.020476             0.351865
# ArticularyWordRecognition     2.563949       0.020888             0.359721
# MotorImagery                  2.989936       0.020672             0.685170
# FingerMovements               1.266975       0.021088             0.379911
#
#                                                                          \
#                           Sampled Controlled ResNet       Sig   Tabular
# Cricket                                    0.292490  0.297703  0.176747
# UWaveGestureLibrary                        0.431089  0.270833  0.160698
# EigenWorms                                 0.282837  0.237815  0.155643
# Epilepsy                                   0.267143  0.257623  0.155393
# Handwriting                                0.318064  0.240531  0.165498
# RacketSports                               0.265560  0.255579  0.159003
# HandMovementDirection                      0.303577  0.238504  0.173719
# Libras                                     0.145186  0.164276  0.090852
# NATOPS                                     0.144738  0.145730  0.100580
# SelfRegulationSCP2                         0.271868  0.243608  0.175049
# Heartbeat                                  0.491812  0.395867  0.172507
# EthanolConcentration                       0.266800  0.258840  0.155256
# SelfRegulationSCP1                         0.284219  0.260475  0.156178
# ArticularyWordRecognition                  0.290073  0.259877  0.164844
# MotorImagery                               0.575028  0.400013  0.179338
# FingerMovements                            0.299975  0.254610  0.176838
#
#
#                           Time Inhomogenous Randomized Signature
# Cricket                                                 0.206088
# UWaveGestureLibrary                                     0.253182
# EigenWorms                                              0.207208
# Epilepsy                                                0.193966
# Handwriting                                             0.252413
# RacketSports                                            0.190757
# HandMovementDirection                                   0.209271
# Libras                                                  0.098368
# NATOPS                                                  0.144479
# SelfRegulationSCP2                                      0.210717
# Heartbeat                                               0.300337
# EthanolConcentration                                    0.196871
# SelfRegulationSCP1                                      0.207635
# ArticularyWordRecognition                               0.208148
# MotorImagery                                            0.413162
# FingerMovements                                         0.195222
#
# [16 rows x 42 columns]

# %%
df_small = pd.read_pickle("TSER_results_small.pkl")

# %%
df_small["acc_test"].mean()
# Out:
# MultiRocket                               0.723939
# Random Guesser                            0.281465
# Randomized Signature                      0.465592
# Sampled Controlled ResNet                 0.629924
# Sig                                       0.545245
# Tabular                                   0.654787
# Time Inhomogenous Randomized Signature    0.475510
# dtype: float64

# %%
df_small["acc_test"].rank(axis=1, ascending=False).mean()
# Out:
# MultiRocket                               1.96875
# Random Guesser                            6.62500
# Randomized Signature                      5.31250
# Sampled Controlled ResNet                 2.87500
# Sig                                       3.87500
# Tabular                                   2.50000
# Time Inhomogenous Randomized Signature    4.84375
# dtype: float64

# %%
df_small["acc_test"].rank(axis=1, ascending=False)
# Out:
#                            MultiRocket  Random Guesser  Randomized Signature  \
# Cricket                            1.0             7.0                   5.0
# UWaveGestureLibrary                1.0             7.0                   6.0
# EigenWorms                         1.0             6.0                   6.0
# Epilepsy                           1.0             7.0                   2.0
# Handwriting                        1.0             7.0                   5.0
# RacketSports                       1.0             7.0                   6.0
# HandMovementDirection              5.0             4.0                   3.0
# Libras                             1.0             7.0                   6.0
# NATOPS                             2.0             7.0                   6.0
# SelfRegulationSCP2                 1.0             7.0                   6.0
# Heartbeat                          4.0             6.0                   6.0
# EthanolConcentration               3.5             7.0                   5.0
# SelfRegulationSCP1                 3.0             7.0                   5.0
# ArticularyWordRecognition          1.0             7.0                   5.0
# MotorImagery                       1.0             6.0                   7.0
# FingerMovements                    4.0             7.0                   6.0
#
#                            Sampled Controlled ResNet  Sig  Tabular  \
# Cricket                                          4.0  2.0      3.0
# UWaveGestureLibrary                              2.0  5.0      3.0
# EigenWorms                                       3.5  2.0      3.5
# Epilepsy                                         3.0  5.0      4.0
# Handwriting                                      4.0  2.5      2.5
# RacketSports                                     3.0  4.0      2.0
# HandMovementDirection                            2.0  7.0      1.0
# Libras                                           2.0  5.0      3.0
# NATOPS                                           3.0  4.0      1.0
# SelfRegulationSCP2                               5.0  3.0      4.0
# Heartbeat                                        1.0  2.5      2.5
# EthanolConcentration                             3.5  6.0      1.0
# SelfRegulationSCP1                               1.0  4.0      2.0
# ArticularyWordRecognition                        2.0  4.0      3.0
# MotorImagery                                     2.0  3.5      3.5
# FingerMovements                                  5.0  2.5      1.0
#
#                            Time Inhomogenous Randomized Signature
# Cricket                                                       6.0
# UWaveGestureLibrary                                           4.0
# EigenWorms                                                    6.0
# Epilepsy                                                      6.0
# Handwriting                                                   6.0
# RacketSports                                                  5.0
# HandMovementDirection                                         6.0
# Libras                                                        4.0
# NATOPS                                                        5.0
# SelfRegulationSCP2                                            2.0
# Heartbeat                                                     6.0
# EthanolConcentration                                          2.0
# SelfRegulationSCP1                                            6.0
# ArticularyWordRecognition                                     6.0
# MotorImagery                                                  5.0
# FingerMovements                                               2.5

# %%
df_small["acc_test"]
# Out:
#                            MultiRocket  Random Guesser  Randomized Signature  \
# Cricket                       0.972222        0.041667              0.736111
# UWaveGestureLibrary           0.946875        0.153125              0.378125
# EigenWorms                    0.816794        0.419847              0.419847
# Epilepsy                      0.992754        0.210145              0.768116
# Handwriting                   0.372941        0.031765              0.135294
# RacketSports                  0.842105        0.250000              0.486842
# HandMovementDirection         0.270270        0.283784              0.310811
# Libras                        0.950000        0.072222              0.288889
# NATOPS                        0.866667        0.150000              0.227778
# SelfRegulationSCP2            0.600000        0.438889              0.500000
# Heartbeat                     0.726829        0.721951              0.721951
# EthanolConcentration          0.403042        0.247148              0.323194
# SelfRegulationSCP1            0.822526        0.552901              0.679181
# ArticularyWordRecognition     0.990000        0.050000              0.553333
# MotorImagery                  0.510000        0.450000              0.440000
# FingerMovements               0.500000        0.430000              0.480000
#
#                            Sampled Controlled ResNet       Sig   Tabular  \
# Cricket                                     0.847222  0.930556  0.875000
# UWaveGestureLibrary                         0.825000  0.593750  0.818750
# EigenWorms                                  0.488550  0.580153  0.488550
# Epilepsy                                    0.652174  0.500000  0.507246
# Handwriting                                 0.151765  0.165882  0.165882
# RacketSports                                0.690789  0.605263  0.796053
# HandMovementDirection                       0.418919  0.189189  0.594595
# Libras                                      0.750000  0.355556  0.600000
# NATOPS                                      0.766667  0.644444  0.877778
# SelfRegulationSCP2                          0.511111  0.527778  0.516667
# Heartbeat                                   0.756098  0.731707  0.731707
# EthanolConcentration                        0.403042  0.300380  0.574144
# SelfRegulationSCP1                          0.890785  0.682594  0.866894
# ArticularyWordRecognition                   0.956667  0.936667  0.953333
# MotorImagery                                0.480000  0.470000  0.470000
# FingerMovements                             0.490000  0.510000  0.640000
#
#                            Time Inhomogenous Randomized Signature
# Cricket                                                  0.347222
# UWaveGestureLibrary                                      0.712500
# EigenWorms                                               0.419847
# Epilepsy                                                 0.304348
# Handwriting                                              0.090588
# RacketSports                                             0.559211
# HandMovementDirection                                    0.216216
# Libras                                                   0.583333
# NATOPS                                                   0.483333
# SelfRegulationSCP2                                       0.555556
# Heartbeat                                                0.721951
# EthanolConcentration                                     0.517110
# SelfRegulationSCP1                                       0.583618
# ArticularyWordRecognition                                0.543333
# MotorImagery                                             0.460000
# FingerMovements                                          0.510000
